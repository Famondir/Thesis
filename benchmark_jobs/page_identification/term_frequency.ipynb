# %% [markdown]
# # Term Frequency and float frequency sorting

# %%
hgb_guv = '''
Gewinn und Verlustrechnung
GuV
1.
    Umsatzerlöse
2.
    Erhöhung oder Verminderung des Bestands an fertigen und unfertigen Erzeugnissen
3.
    andere aktivierte Eigenleistungen
4.
    sonstige betriebliche Erträge
5.
    Materialaufwand:

    a)
        Aufwendungen für Roh-, Hilfs- und Betriebsstoffe und für bezogene Waren
    b)
        Aufwendungen für bezogene Leistungen

6.
    Personalaufwand:

    a)
        Löhne und Gehälter
    b)
        soziale Abgaben und Aufwendungen für Altersversorgung und für Unterstützung,
        davon für Altersversorgung

7.
    Abschreibungen:

    a)
        auf immaterielle Vermögensgegenstände des Anlagevermögens und Sachanlagen
    b)
        auf Vermögensgegenstände des Umlaufvermögens, soweit diese die in der Kapitalgesellschaft üblichen Abschreibungen überschreiten

8.
    sonstige betriebliche Aufwendungen
9.
    Erträge aus Beteiligungen,
    davon aus verbundenen Unternehmen
10.
    Erträge aus anderen Wertpapieren und Ausleihungen des Finanzanlagevermögens,
    davon aus verbundenen Unternehmen
11.
    sonstige Zinsen und ähnliche Erträge,
    davon aus verbundenen Unternehmen
12.
    Abschreibungen auf Finanzanlagen und auf Wertpapiere des Umlaufvermögens
13.
    Zinsen und ähnliche Aufwendungen,
    davon an verbundene Unternehmen
14.
    Steuern vom Einkommen und vom Ertrag
15.
    Ergebnis nach Steuern
16.
    sonstige Steuern
17.
    Jahresüberschuss/Jahresfehlbetrag.

1.
    Umsatzerlöse
2.
    Herstellungskosten der zur Erzielung der Umsatzerlöse erbrachten Leistungen
3.
    Bruttoergebnis vom Umsatz
4.
    Vertriebskosten
5.
    allgemeine Verwaltungskosten
6.
    sonstige betriebliche Erträge
7.
    sonstige betriebliche Aufwendungen
8.
    Erträge aus Beteiligungen,
    davon aus verbundenen Unternehmen
9.
    Erträge aus anderen Wertpapieren und Ausleihungen des Finanzanlagevermögens,
    davon aus verbundenen Unternehmen
10.
    sonstige Zinsen und ähnliche Erträge,
    davon aus verbundenen Unternehmen
11.
    Abschreibungen auf Finanzanlagen und auf Wertpapiere des Umlaufvermögens
12.
    Zinsen und ähnliche Aufwendungen,
    davon an verbundene Unternehmen
13.
    Steuern vom Einkommen und vom Ertrag
14.
    Ergebnis nach Steuern
15.
    sonstige Steuern
16.
    Jahresüberschuss/Jahresfehlbetrag.

1.
    Umsatzerlöse,
2.
    sonstige Erträge,
3.
    Materialaufwand,
4.
    Personalaufwand,
5.
    Abschreibungen,
6.
    sonstige Aufwendungen,
7.
    Steuern,
8.
    Jahresüberschuss/Jahresfehlbetrag.
'''

hgb_aktiva = '''
Aktivseite
Aktiva

A.
    Anlagevermögen:

    I.
        Immaterielle Vermögensgegenstände:

        1.
            Selbst geschaffene gewerbliche Schutzrechte und ähnliche Rechte und Werte;
        2.
            entgeltlich erworbene Konzessionen, gewerbliche Schutzrechte und ähnliche Rechte und Werte sowie Lizenzen an solchen Rechten und Werten;
        3.
            Geschäfts- oder Firmenwert;
        4.
            geleistete Anzahlungen;

    II.
        Sachanlagen:

        1.
            Grundstücke, grundstücksgleiche Rechte und Bauten einschließlich der Bauten auf fremden Grundstücken;
        2.
            technische Anlagen und Maschinen;
        3.
            andere Anlagen, Betriebs- und Geschäftsausstattung;
        4.
            geleistete Anzahlungen und Anlagen im Bau;

    III.
        Finanzanlagen:

        1.
            Anteile an verbundenen Unternehmen;
        2.
            Ausleihungen an verbundene Unternehmen;
        3.
            Beteiligungen;
        4.
            Ausleihungen an Unternehmen, mit denen ein Beteiligungsverhältnis besteht;
        5.
            Wertpapiere des Anlagevermögens;
        6.
            sonstige Ausleihungen.

B.
    Umlaufvermögen:

    I.
        Vorräte:

        1.
            Roh-, Hilfs- und Betriebsstoffe;
        2.
            unfertige Erzeugnisse, unfertige Leistungen;
        3.
            fertige Erzeugnisse und Waren;
        4.
            geleistete Anzahlungen;

    II.
        Forderungen und sonstige Vermögensgegenstände:

        1.
            Forderungen aus Lieferungen und Leistungen;
        2.
            Forderungen gegen verbundene Unternehmen;
        3.
            Forderungen gegen Unternehmen, mit denen ein Beteiligungsverhältnis besteht;
        4.
            sonstige Vermögensgegenstände;

    III.
        Wertpapiere:

        1.
            Anteile an verbundenen Unternehmen;
        2.
            sonstige Wertpapiere;

    IV.
        Kassenbestand, Bundesbankguthaben, Guthaben bei Kreditinstituten und Schecks.

C.
    Rechnungsabgrenzungsposten.
D.
    Aktive latente Steuern.
E.
    Aktiver Unterschiedsbetrag aus der Vermögensverrechnung.
'''

hgb_passiva = '''
(3) Passivseite
Passiva

A.
    Eigenkapital:

    I.
        Gezeichnetes Kapital;
    II.
        Kapitalrücklage;
    III.
        Gewinnrücklagen:

        1.
            gesetzliche Rücklage;
        2.
            Rücklage für Anteile an einem herrschenden oder mehrheitlich beteiligten Unternehmen;
        3.
            satzungsmäßige Rücklagen;
        4.
            andere Gewinnrücklagen;

    IV.
        Gewinnvortrag/Verlustvortrag;
    V.
        Jahresüberschuß/Jahresfehlbetrag.

B.
    Rückstellungen:

    1.
        Rückstellungen für Pensionen und ähnliche Verpflichtungen;
    2.
        Steuerrückstellungen;
    3.
        sonstige Rückstellungen.

C.
    Verbindlichkeiten:

    1.
        Anleihen,
        davon konvertibel;
    2.
        Verbindlichkeiten gegenüber Kreditinstituten;
    3.
        erhaltene Anzahlungen auf Bestellungen;
    4.
        Verbindlichkeiten aus Lieferungen und Leistungen;
    5.
        Verbindlichkeiten aus der Annahme gezogener Wechsel und der Ausstellung eigener Wechsel;
    6.
        Verbindlichkeiten gegenüber verbundenen Unternehmen;
    7.
        Verbindlichkeiten gegenüber Unternehmen, mit denen ein Beteiligungsverhältnis besteht;
    8.
        sonstige Verbindlichkeiten,
        davon aus Steuern,
        davon im Rahmen der sozialen Sicherheit.

D.
    Rechnungsabgrenzungsposten.
E.
    Passive latente Steuern.
'''

# %%
import json

with open("/home/simon/Documents/data_science/Thesis/Python/pdf_texts.json") as f:
    texts = json.load(f)

# %%
import re
from nltk.corpus import stopwords

import nltk
nltk.download('stopwords')

non_filling_words = {
    'GuV': set(),
    'Aktiva': set(),
    'Passiva': set()
}

additional_words = '''
Vorjahr
Geschäftsjahr
'''

for entry in [('GuV', hgb_guv), ('Aktiva', hgb_aktiva), ('Passiva', hgb_passiva)]:
    # Remove line breaks and split into words
    words = re.findall(r'\b\w+\b', entry[1]+additional_words)

    # Get German stopwords from nltk
    filling_words = set(stopwords.words('german'))

    # Get non-filling words
    non_filling_words[entry[0]] = {word for word in words if (word.lower() not in filling_words) and (not re.match(r'^\d+', word)) and (len(word) > 2) and word[0].isupper()}
# Out:
# [nltk_data] Downloading package stopwords to /home/simon/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
tf_dict = {}

for key, value in texts.items():
    for i, entry in enumerate(value):
        for type, words in non_filling_words.items():
            word_counts = {word: entry.lower().count(word.lower()) for word in words}
            date_count = sum(1 for word in re.findall(r'\d{2}\.\d{2}\.\d{4}', entry))  # Count occurrences of 4-digit numbers (years)
            float_count = sum(1 for word in re.findall(r'\d+\.?(\d{3}\.?)*\,?\d{0,2}', entry))  # Count occurrences of numbers
            integer_count = sum(1 for word in re.findall(r'(?<![\d\.,])\d+(?![\d\.,])', entry))
            tf_dict[f"{key}_{i}_{type}"] = {
                'word_counts': word_counts, 
                'total_words': len(re.findall(r'\b\w+\b', entry)), 
                'page': i + 1, 
                'type': type, 
                'file_path': key, 
                'date_count': date_count, 
                'float_count': float_count,
                'integer_count': integer_count
            }
    # break

tf_dict
# Out:
# {'/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_0_GuV': {'word_counts': {'Steuern': 0,
#    'Einkommen': 0,
#    'Umsatzerlöse': 0,
#    'Abgaben': 0,
#    'Bestands': 0,
#    'Jahresüberschuss': 0,
#    'Umsatz': 0,
#    'Finanzanlagevermögens': 0,
#    'Ertrag': 0,
#    'Geschäftsjahr': 1,
#    'Sachanlagen': 0,
#    'Anlagevermögens': 0,
#    'Vermögensgegenstände': 0,
#    'Vorjahr': 0,
#    'Hilfs': 0,
#    'Aufwendungen': 0,
#    'Kapitalgesellschaft': 0,
#    'Zinsen': 0,
#    'Erhöhung': 0,
#    'Verminderung': 0,
#    'Erträge': 0,
#    'Ergebnis': 0,
#    'Bruttoergebnis': 0,
#    'Löhne': 0,
#    'Altersversorgung': 0,
#    'Wertpapiere': 0,
#    'Vertriebskosten': 0,
#    'Betriebsstoffe': 0,
#    'Unterstützung': 0,
#    'Abschreibungen': 0,
#    'Verwaltungskosten': 0,
#    'Roh': 0,
#    'Finanzanlagen': 0,
#    'Gewinn': 0,
#    'Leistungen': 0,
#    'Umlaufvermögens': 0,
#    'Beteiligungen': 0,
#    'Unternehmen': 0,
#    'Erzeugnissen': 0,
#    'Eigenleistungen': 0,
#    'Materialaufwand': 0,
#    'Herstellungskosten': 0,
#    'Personalaufwand': 0,
#    'Erzielung': 0,
#    'Gehälter': 0,
#    'Ausleihungen': 0,
#    'Verlustrechnung': 0,
#    'Jahresfehlbetrag': 0,
#    'Wertpapieren': 0,
#    'GuV': 0},
#   'total_words': 30,
#   'page': 1,
#   'type': 'GuV',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 0,
#   'float_count': 5,
#   'integer_count': 2},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_0_Aktiva': {'word_counts': {'Anteile': 0,
#    'Steuern': 0,
#    'Werten': 0,
#    'Erzeugnisse': 0,
#    'Forderungen': 0,
#    'III': 0,
#    'Bundesbankguthaben': 0,
#    'Immaterielle': 0,
#    'Geschäftsjahr': 1,
#    'Aktivseite': 0,
#    'Rechnungsabgrenzungsposten': 0,
#    'Anlagen': 0,
#    'Kassenbestand': 0,
#    'Sachanlagen': 0,
#    'Umlaufvermögen': 0,
#    'Anlagevermögens': 0,
#    'Rechte': 0,
#    'Vermögensgegenstände': 0,
#    'Vorjahr': 0,
#    'Unterschiedsbetrag': 0,
#    'Hilfs': 0,
#    'Aktiva': 0,
#    'Guthaben': 0,
#    'Kreditinstituten': 0,
#    'Konzessionen': 0,
#    'Vorräte': 0,
#    'Bauten': 0,
#    'Wertpapiere': 0,
#    'Betriebsstoffe': 0,
#    'Firmenwert': 0,
#    'Betriebs': 0,
#    'Anlagevermögen': 0,
#    'Roh': 0,
#    'Finanzanlagen': 0,
#    'Schecks': 0,
#    'Lizenzen': 0,
#    'Grundstücken': 0,
#    'Lieferungen': 0,
#    'Werte': 0,
#    'Anzahlungen': 0,
#    'Geschäftsausstattung': 0,
#    'Rechten': 0,
#    'Bau': 0,
#    'Beteiligungsverhältnis': 0,
#    'Beteiligungen': 0,
#    'Maschinen': 0,
#    'Unternehmen': 0,
#    'Leistungen': 0,
#    'Aktiver': 0,
#    'Vermögensverrechnung': 0,
#    'Aktive': 0,
#    'Grundstücke': 0,
#    'Ausleihungen': 0,
#    'Schutzrechte': 0,
#    'Geschäfts': 1},
#   'total_words': 30,
#   'page': 1,
#   'type': 'Aktiva',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 0,
#   'float_count': 5,
#   'integer_count': 2},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_0_Passiva': {'word_counts': {'Anteile': 0,
#    'Steuern': 0,
#    'Kapitalrücklage': 0,
#    'Passivseite': 0,
#    'III': 0,
#    'Gewinnrücklagen': 0,
#    'Verlustvortrag': 0,
#    'Eigenkapital': 0,
#    'Sicherheit': 0,
#    'Jahresüberschuß': 0,
#    'Rechnungsabgrenzungsposten': 0,
#    'Geschäftsjahr': 1,
#    'Vorjahr': 0,
#    'Verpflichtungen': 0,
#    'Annahme': 0,
#    'Gezeichnetes': 0,
#    'Kreditinstituten': 0,
#    'Verbindlichkeiten': 0,
#    'Rückstellungen': 0,
#    'Pensionen': 0,
#    'Passiva': 0,
#    'Lieferungen': 0,
#    'Steuerrückstellungen': 0,
#    'Rücklagen': 0,
#    'Leistungen': 0,
#    'Anzahlungen': 0,
#    'Anleihen': 0,
#    'Beteiligungsverhältnis': 0,
#    'Unternehmen': 0,
#    'Kapital': 0,
#    'Rücklage': 0,
#    'Bestellungen': 0,
#    'Jahresfehlbetrag': 0,
#    'Rahmen': 0,
#    'Wechsel': 0,
#    'Gewinnvortrag': 0,
#    'Ausstellung': 0,
#    'Passive': 0},
#   'total_words': 30,
#   'page': 1,
#   'type': 'Passiva',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 0,
#   'float_count': 5,
#   'integer_count': 2},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_1_GuV': {'word_counts': {'Steuern': 0,
#    'Einkommen': 0,
#    'Umsatzerlöse': 0,
#    'Abgaben': 0,
#    'Bestands': 0,
#    'Jahresüberschuss': 0,
#    'Umsatz': 0,
#    'Finanzanlagevermögens': 0,
#    'Ertrag': 0,
#    'Geschäftsjahr': 0,
#    'Sachanlagen': 0,
#    'Anlagevermögens': 0,
#    'Vermögensgegenstände': 0,
#    'Vorjahr': 0,
#    'Hilfs': 0,
#    'Aufwendungen': 0,
#    'Kapitalgesellschaft': 0,
#    'Zinsen': 0,
#    'Erhöhung': 0,
#    'Verminderung': 0,
#    'Erträge': 0,
#    'Ergebnis': 0,
#    'Bruttoergebnis': 0,
#    'Löhne': 0,
#    'Altersversorgung': 0,
#    'Wertpapiere': 0,
#    'Vertriebskosten': 0,
#    'Betriebsstoffe': 0,
#    'Unterstützung': 0,
#    'Abschreibungen': 0,
#    'Verwaltungskosten': 0,
#    'Roh': 0,
#    'Finanzanlagen': 0,
#    'Gewinn': 0,
#    'Leistungen': 0,
#    'Umlaufvermögens': 0,
#    'Beteiligungen': 0,
#    'Unternehmen': 0,
#    'Erzeugnissen': 0,
#    'Eigenleistungen': 0,
#    'Materialaufwand': 0,
#    'Herstellungskosten': 0,
#    'Personalaufwand': 0,
#    'Erzielung': 0,
#    'Gehälter': 0,
#    'Ausleihungen': 0,
#    'Verlustrechnung': 0,
#    'Jahresfehlbetrag': 0,
#    'Wertpapieren': 0,
#    'GuV': 0},
#   'total_words': 3,
#   'page': 2,
#   'type': 'GuV',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 0,
#   'float_count': 2,
#   'integer_count': 1},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_1_Aktiva': {'word_counts': {'Anteile': 0,
#    'Steuern': 0,
#    'Werten': 0,
#    'Erzeugnisse': 0,
#    'Forderungen': 0,
#    'III': 0,
#    'Bundesbankguthaben': 0,
#    'Immaterielle': 0,
#    'Geschäftsjahr': 0,
#    'Aktivseite': 0,
#    'Rechnungsabgrenzungsposten': 0,
#    'Anlagen': 0,
#    'Kassenbestand': 0,
#    'Sachanlagen': 0,
#    'Umlaufvermögen': 0,
#    'Anlagevermögens': 0,
#    'Rechte': 0,
#    'Vermögensgegenstände': 0,
#    'Vorjahr': 0,
#    'Unterschiedsbetrag': 0,
#    'Hilfs': 0,
#    'Aktiva': 0,
#    'Guthaben': 0,
#    'Kreditinstituten': 0,
#    'Konzessionen': 0,
#    'Vorräte': 0,
#    'Bauten': 0,
#    'Wertpapiere': 0,
#    'Betriebsstoffe': 0,
#    'Firmenwert': 0,
#    'Betriebs': 0,
#    'Anlagevermögen': 0,
#    'Roh': 0,
#    'Finanzanlagen': 0,
#    'Schecks': 0,
#    'Lizenzen': 0,
#    'Grundstücken': 0,
#    'Lieferungen': 0,
#    'Werte': 0,
#    'Anzahlungen': 0,
#    'Geschäftsausstattung': 0,
#    'Rechten': 0,
#    'Bau': 0,
#    'Beteiligungsverhältnis': 0,
#    'Beteiligungen': 0,
#    'Maschinen': 0,
#    'Unternehmen': 0,
#    'Leistungen': 0,
#    'Aktiver': 0,
#    'Vermögensverrechnung': 0,
#    'Aktive': 0,
#    'Grundstücke': 0,
#    'Ausleihungen': 0,
#    'Schutzrechte': 0,
#    'Geschäfts': 0},
#   'total_words': 3,
#   'page': 2,
#   'type': 'Aktiva',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 0,
#   'float_count': 2,
#   'integer_count': 1},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_1_Passiva': {'word_counts': {'Anteile': 0,
#    'Steuern': 0,
#    'Kapitalrücklage': 0,
#    'Passivseite': 0,
#    'III': 0,
#    'Gewinnrücklagen': 0,
#    'Verlustvortrag': 0,
#    'Eigenkapital': 0,
#    'Sicherheit': 0,
#    'Jahresüberschuß': 0,
#    'Rechnungsabgrenzungsposten': 0,
#    'Geschäftsjahr': 0,
#    'Vorjahr': 0,
#    'Verpflichtungen': 0,
#    'Annahme': 0,
#    'Gezeichnetes': 0,
#    'Kreditinstituten': 0,
#    'Verbindlichkeiten': 0,
#    'Rückstellungen': 0,
#    'Pensionen': 0,
#    'Passiva': 0,
#    'Lieferungen': 0,
#    'Steuerrückstellungen': 0,
#    'Rücklagen': 0,
#    'Leistungen': 0,
#    'Anzahlungen': 0,
#    'Anleihen': 0,
#    'Beteiligungsverhältnis': 0,
#    'Unternehmen': 0,
#    'Kapital': 0,
#    'Rücklage': 0,
#    'Bestellungen': 0,
#    'Jahresfehlbetrag': 0,
#    'Rahmen': 0,
#    'Wechsel': 0,
#    'Gewinnvortrag': 0,
#    'Ausstellung': 0,
#    'Passive': 0},
#   'total_words': 3,
#   'page': 2,
#   'type': 'Passiva',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 0,
#   'float_count': 2,
#   'integer_count': 1},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_2_GuV': {'word_counts': {'Steuern': 0,
#    'Einkommen': 0,
#    'Umsatzerlöse': 0,
#    'Abgaben': 0,
#    'Bestands': 0,
#    'Jahresüberschuss': 0,
#    'Umsatz': 0,
#    'Finanzanlagevermögens': 0,
#    'Ertrag': 0,
#    'Geschäftsjahr': 2,
#    'Sachanlagen': 0,
#    'Anlagevermögens': 0,
#    'Vermögensgegenstände': 0,
#    'Vorjahr': 0,
#    'Hilfs': 0,
#    'Aufwendungen': 0,
#    'Kapitalgesellschaft': 0,
#    'Zinsen': 0,
#    'Erhöhung': 0,
#    'Verminderung': 0,
#    'Erträge': 0,
#    'Ergebnis': 0,
#    'Bruttoergebnis': 0,
#    'Löhne': 0,
#    'Altersversorgung': 0,
#    'Wertpapiere': 0,
#    'Vertriebskosten': 0,
#    'Betriebsstoffe': 0,
#    'Unterstützung': 0,
#    'Abschreibungen': 0,
#    'Verwaltungskosten': 0,
#    'Roh': 0,
#    'Finanzanlagen': 0,
#    'Gewinn': 1,
#    'Leistungen': 0,
#    'Umlaufvermögens': 0,
#    'Beteiligungen': 0,
#    'Unternehmen': 0,
#    'Erzeugnissen': 0,
#    'Eigenleistungen': 0,
#    'Materialaufwand': 0,
#    'Herstellungskosten': 0,
#    'Personalaufwand': 0,
#    'Erzielung': 0,
#    'Gehälter': 0,
#    'Ausleihungen': 0,
#    'Verlustrechnung': 1,
#    'Jahresfehlbetrag': 0,
#    'Wertpapieren': 0,
#    'GuV': 0},
#   'total_words': 68,
#   'page': 3,
#   'type': 'GuV',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 0,
#   'float_count': 24,
#   'integer_count': 9},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_2_Aktiva': {'word_counts': {'Anteile': 0,
#    'Steuern': 0,
#    'Werten': 0,
#    'Erzeugnisse': 0,
#    'Forderungen': 0,
#    'III': 0,
#    'Bundesbankguthaben': 0,
#    'Immaterielle': 0,
#    'Geschäftsjahr': 2,
#    'Aktivseite': 0,
#    'Rechnungsabgrenzungsposten': 0,
#    'Anlagen': 1,
#    'Kassenbestand': 0,
#    'Sachanlagen': 0,
#    'Umlaufvermögen': 0,
#    'Anlagevermögens': 0,
#    'Rechte': 0,
#    'Vermögensgegenstände': 0,
#    'Vorjahr': 0,
#    'Unterschiedsbetrag': 0,
#    'Hilfs': 0,
#    'Aktiva': 0,
#    'Guthaben': 0,
#    'Kreditinstituten': 0,
#    'Konzessionen': 0,
#    'Vorräte': 0,
#    'Bauten': 0,
#    'Wertpapiere': 0,
#    'Betriebsstoffe': 0,
#    'Firmenwert': 0,
#    'Betriebs': 0,
#    'Anlagevermögen': 0,
#    'Roh': 0,
#    'Finanzanlagen': 0,
#    'Schecks': 0,
#    'Lizenzen': 0,
#    'Grundstücken': 0,
#    'Lieferungen': 0,
#    'Werte': 0,
#    'Anzahlungen': 0,
#    'Geschäftsausstattung': 0,
#    'Rechten': 0,
#    'Bau': 0,
#    'Beteiligungsverhältnis': 0,
#    'Beteiligungen': 0,
#    'Maschinen': 0,
#    'Unternehmen': 0,
#    'Leistungen': 0,
#    'Aktiver': 0,
#    'Vermögensverrechnung': 0,
#    'Aktive': 0,
#    'Grundstücke': 0,
#    'Ausleihungen': 0,
#    'Schutzrechte': 0,
#    'Geschäfts': 2},
#   'total_words': 68,
#   'page': 3,
#   'type': 'Aktiva',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 0,
#   'float_count': 24,
#   'integer_count': 9},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_2_Passiva': {'word_counts': {'Anteile': 0,
#    'Steuern': 0,
#    'Kapitalrücklage': 0,
#    'Passivseite': 0,
#    'III': 0,
#    'Gewinnrücklagen': 0,
#    'Verlustvortrag': 0,
#    'Eigenkapital': 0,
#    'Sicherheit': 0,
#    'Jahresüberschuß': 0,
#    'Rechnungsabgrenzungsposten': 0,
#    'Geschäftsjahr': 2,
#    'Vorjahr': 0,
#    'Verpflichtungen': 0,
#    'Annahme': 0,
#    'Gezeichnetes': 0,
#    'Kreditinstituten': 0,
#    'Verbindlichkeiten': 0,
#    'Rückstellungen': 0,
#    'Pensionen': 0,
#    'Passiva': 0,
#    'Lieferungen': 0,
#    'Steuerrückstellungen': 0,
#    'Rücklagen': 0,
#    'Leistungen': 0,
#    'Anzahlungen': 0,
#    'Anleihen': 0,
#    'Beteiligungsverhältnis': 0,
#    'Unternehmen': 0,
#    'Kapital': 0,
#    'Rücklage': 0,
#    'Bestellungen': 0,
#    'Jahresfehlbetrag': 0,
#    'Rahmen': 0,
#    'Wechsel': 0,
#    'Gewinnvortrag': 0,
#    'Ausstellung': 0,
#    'Passive': 0},
#   'total_words': 68,
#   'page': 3,
#   'type': 'Passiva',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 0,
#   'float_count': 24,
#   'integer_count': 9},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_3_GuV': {'word_counts': {'Steuern': 0,
#    'Einkommen': 0,
#    'Umsatzerlöse': 0,
#    'Abgaben': 0,
#    'Bestands': 0,
#    'Jahresüberschuss': 0,
#    'Umsatz': 0,
#    'Finanzanlagevermögens': 0,
#    'Ertrag': 0,
#    'Geschäftsjahr': 0,
#    'Sachanlagen': 0,
#    'Anlagevermögens': 0,
#    'Vermögensgegenstände': 0,
#    'Vorjahr': 0,
#    'Hilfs': 0,
#    'Aufwendungen': 0,
#    'Kapitalgesellschaft': 0,
#    'Zinsen': 0,
#    'Erhöhung': 0,
#    'Verminderung': 0,
#    'Erträge': 0,
#    'Ergebnis': 0,
#    'Bruttoergebnis': 0,
#    'Löhne': 0,
#    'Altersversorgung': 0,
#    'Wertpapiere': 0,
#    'Vertriebskosten': 0,
#    'Betriebsstoffe': 0,
#    'Unterstützung': 0,
#    'Abschreibungen': 0,
#    'Verwaltungskosten': 0,
#    'Roh': 0,
#    'Finanzanlagen': 0,
#    'Gewinn': 0,
#    'Leistungen': 0,
#    'Umlaufvermögens': 0,
#    'Beteiligungen': 0,
#    'Unternehmen': 0,
#    'Erzeugnissen': 0,
#    'Eigenleistungen': 0,
#    'Materialaufwand': 0,
#    'Herstellungskosten': 0,
#    'Personalaufwand': 0,
#    'Erzielung': 0,
#    'Gehälter': 0,
#    'Ausleihungen': 0,
#    'Verlustrechnung': 0,
#    'Jahresfehlbetrag': 0,
#    'Wertpapieren': 0,
#    'GuV': 0},
#   'total_words': 0,
#   'page': 4,
#   'type': 'GuV',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 0,
#   'float_count': 0,
#   'integer_count': 0},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_3_Aktiva': {'word_counts': {'Anteile': 0,
#    'Steuern': 0,
#    'Werten': 0,
#    'Erzeugnisse': 0,
#    'Forderungen': 0,
#    'III': 0,
#    'Bundesbankguthaben': 0,
#    'Immaterielle': 0,
#    'Geschäftsjahr': 0,
#    'Aktivseite': 0,
#    'Rechnungsabgrenzungsposten': 0,
#    'Anlagen': 0,
#    'Kassenbestand': 0,
#    'Sachanlagen': 0,
#    'Umlaufvermögen': 0,
#    'Anlagevermögens': 0,
#    'Rechte': 0,
#    'Vermögensgegenstände': 0,
#    'Vorjahr': 0,
#    'Unterschiedsbetrag': 0,
#    'Hilfs': 0,
#    'Aktiva': 0,
#    'Guthaben': 0,
#    'Kreditinstituten': 0,
#    'Konzessionen': 0,
#    'Vorräte': 0,
#    'Bauten': 0,
#    'Wertpapiere': 0,
#    'Betriebsstoffe': 0,
#    'Firmenwert': 0,
#    'Betriebs': 0,
#    'Anlagevermögen': 0,
#    'Roh': 0,
#    'Finanzanlagen': 0,
#    'Schecks': 0,
#    'Lizenzen': 0,
#    'Grundstücken': 0,
#    'Lieferungen': 0,
#    'Werte': 0,
#    'Anzahlungen': 0,
#    'Geschäftsausstattung': 0,
#    'Rechten': 0,
#    'Bau': 0,
#    'Beteiligungsverhältnis': 0,
#    'Beteiligungen': 0,
#    'Maschinen': 0,
#    'Unternehmen': 0,
#    'Leistungen': 0,
#    'Aktiver': 0,
#    'Vermögensverrechnung': 0,
#    'Aktive': 0,
#    'Grundstücke': 0,
#    'Ausleihungen': 0,
#    'Schutzrechte': 0,
#    'Geschäfts': 0},
#   'total_words': 0,
#   'page': 4,
#   'type': 'Aktiva',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 0,
#   'float_count': 0,
#   'integer_count': 0},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_3_Passiva': {'word_counts': {'Anteile': 0,
#    'Steuern': 0,
#    'Kapitalrücklage': 0,
#    'Passivseite': 0,
#    'III': 0,
#    'Gewinnrücklagen': 0,
#    'Verlustvortrag': 0,
#    'Eigenkapital': 0,
#    'Sicherheit': 0,
#    'Jahresüberschuß': 0,
#    'Rechnungsabgrenzungsposten': 0,
#    'Geschäftsjahr': 0,
#    'Vorjahr': 0,
#    'Verpflichtungen': 0,
#    'Annahme': 0,
#    'Gezeichnetes': 0,
#    'Kreditinstituten': 0,
#    'Verbindlichkeiten': 0,
#    'Rückstellungen': 0,
#    'Pensionen': 0,
#    'Passiva': 0,
#    'Lieferungen': 0,
#    'Steuerrückstellungen': 0,
#    'Rücklagen': 0,
#    'Leistungen': 0,
#    'Anzahlungen': 0,
#    'Anleihen': 0,
#    'Beteiligungsverhältnis': 0,
#    'Unternehmen': 0,
#    'Kapital': 0,
#    'Rücklage': 0,
#    'Bestellungen': 0,
#    'Jahresfehlbetrag': 0,
#    'Rahmen': 0,
#    'Wechsel': 0,
#    'Gewinnvortrag': 0,
#    'Ausstellung': 0,
#    'Passive': 0},
#   'total_words': 0,
#   'page': 4,
#   'type': 'Passiva',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 0,
#   'float_count': 0,
#   'integer_count': 0},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_4_GuV': {'word_counts': {'Steuern': 0,
#    'Einkommen': 0,
#    'Umsatzerlöse': 0,
#    'Abgaben': 0,
#    'Bestands': 0,
#    'Jahresüberschuss': 0,
#    'Umsatz': 0,
#    'Finanzanlagevermögens': 0,
#    'Ertrag': 0,
#    'Geschäftsjahr': 1,
#    'Sachanlagen': 0,
#    'Anlagevermögens': 0,
#    'Vermögensgegenstände': 0,
#    'Vorjahr': 0,
#    'Hilfs': 0,
#    'Aufwendungen': 0,
#    'Kapitalgesellschaft': 0,
#    'Zinsen': 0,
#    'Erhöhung': 0,
#    'Verminderung': 0,
#    'Erträge': 0,
#    'Ergebnis': 0,
#    'Bruttoergebnis': 0,
#    'Löhne': 0,
#    'Altersversorgung': 0,
#    'Wertpapiere': 0,
#    'Vertriebskosten': 0,
#    'Betriebsstoffe': 0,
#    'Unterstützung': 0,
#    'Abschreibungen': 0,
#    'Verwaltungskosten': 0,
#    'Roh': 0,
#    'Finanzanlagen': 0,
#    'Gewinn': 0,
#    'Leistungen': 0,
#    'Umlaufvermögens': 0,
#    'Beteiligungen': 0,
#    'Unternehmen': 0,
#    'Erzeugnissen': 0,
#    'Eigenleistungen': 0,
#    'Materialaufwand': 0,
#    'Herstellungskosten': 0,
#    'Personalaufwand': 0,
#    'Erzielung': 0,
#    'Gehälter': 0,
#    'Ausleihungen': 0,
#    'Verlustrechnung': 0,
#    'Jahresfehlbetrag': 0,
#    'Wertpapieren': 0,
#    'GuV': 0},
#   'total_words': 27,
#   'page': 5,
#   'type': 'GuV',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 0,
#   'float_count': 9,
#   'integer_count': 6},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_4_Aktiva': {'word_counts': {'Anteile': 0,
#    'Steuern': 0,
#    'Werten': 0,
#    'Erzeugnisse': 0,
#    'Forderungen': 0,
#    'III': 0,
#    'Bundesbankguthaben': 0,
#    'Immaterielle': 0,
#    'Geschäftsjahr': 1,
#    'Aktivseite': 0,
#    'Rechnungsabgrenzungsposten': 0,
#    'Anlagen': 0,
#    'Kassenbestand': 0,
#    'Sachanlagen': 0,
#    'Umlaufvermögen': 0,
#    'Anlagevermögens': 0,
#    'Rechte': 0,
#    'Vermögensgegenstände': 0,
#    'Vorjahr': 0,
#    'Unterschiedsbetrag': 0,
#    'Hilfs': 0,
#    'Aktiva': 0,
#    'Guthaben': 0,
#    'Kreditinstituten': 0,
#    'Konzessionen': 0,
#    'Vorräte': 0,
#    'Bauten': 0,
#    'Wertpapiere': 0,
#    'Betriebsstoffe': 0,
#    'Firmenwert': 0,
#    'Betriebs': 0,
#    'Anlagevermögen': 0,
#    'Roh': 0,
#    'Finanzanlagen': 0,
#    'Schecks': 0,
#    'Lizenzen': 0,
#    'Grundstücken': 0,
#    'Lieferungen': 0,
#    'Werte': 0,
#    'Anzahlungen': 0,
#    'Geschäftsausstattung': 0,
#    'Rechten': 0,
#    'Bau': 0,
#    'Beteiligungsverhältnis': 0,
#    'Beteiligungen': 0,
#    'Maschinen': 0,
#    'Unternehmen': 0,
#    'Leistungen': 0,
#    'Aktiver': 0,
#    'Vermögensverrechnung': 0,
#    'Aktive': 0,
#    'Grundstücke': 0,
#    'Ausleihungen': 0,
#    'Schutzrechte': 0,
#    'Geschäfts': 1},
#   'total_words': 27,
#   'page': 5,
#   'type': 'Aktiva',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 0,
#   'float_count': 9,
#   'integer_count': 6},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_4_Passiva': {'word_counts': {'Anteile': 0,
#    'Steuern': 0,
#    'Kapitalrücklage': 0,
#    'Passivseite': 0,
#    'III': 0,
#    'Gewinnrücklagen': 0,
#    'Verlustvortrag': 0,
#    'Eigenkapital': 0,
#    'Sicherheit': 0,
#    'Jahresüberschuß': 0,
#    'Rechnungsabgrenzungsposten': 0,
#    'Geschäftsjahr': 1,
#    'Vorjahr': 0,
#    'Verpflichtungen': 0,
#    'Annahme': 0,
#    'Gezeichnetes': 0,
#    'Kreditinstituten': 0,
#    'Verbindlichkeiten': 0,
#    'Rückstellungen': 0,
#    'Pensionen': 0,
#    'Passiva': 0,
#    'Lieferungen': 0,
#    'Steuerrückstellungen': 0,
#    'Rücklagen': 0,
#    'Leistungen': 0,
#    'Anzahlungen': 0,
#    'Anleihen': 0,
#    'Beteiligungsverhältnis': 0,
#    'Unternehmen': 0,
#    'Kapital': 0,
#    'Rücklage': 0,
#    'Bestellungen': 0,
#    'Jahresfehlbetrag': 0,
#    'Rahmen': 0,
#    'Wechsel': 0,
#    'Gewinnvortrag': 0,
#    'Ausstellung': 0,
#    'Passive': 0},
#   'total_words': 27,
#   'page': 5,
#   'type': 'Passiva',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 0,
#   'float_count': 9,
#   'integer_count': 6},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_5_GuV': {'word_counts': {'Steuern': 0,
#    'Einkommen': 0,
#    'Umsatzerlöse': 0,
#    'Abgaben': 0,
#    'Bestands': 0,
#    'Jahresüberschuss': 0,
#    'Umsatz': 0,
#    'Finanzanlagevermögens': 0,
#    'Ertrag': 1,
#    'Geschäftsjahr': 0,
#    'Sachanlagen': 0,
#    'Anlagevermögens': 0,
#    'Vermögensgegenstände': 0,
#    'Vorjahr': 0,
#    'Hilfs': 0,
#    'Aufwendungen': 0,
#    'Kapitalgesellschaft': 0,
#    'Zinsen': 0,
#    'Erhöhung': 0,
#    'Verminderung': 0,
#    'Erträge': 0,
#    'Ergebnis': 0,
#    'Bruttoergebnis': 0,
#    'Löhne': 0,
#    'Altersversorgung': 0,
#    'Wertpapiere': 0,
#    'Vertriebskosten': 0,
#    'Betriebsstoffe': 0,
#    'Unterstützung': 0,
#    'Abschreibungen': 0,
#    'Verwaltungskosten': 0,
#    'Roh': 0,
#    'Finanzanlagen': 0,
#    'Gewinn': 0,
#    'Leistungen': 0,
#    'Umlaufvermögens': 0,
#    'Beteiligungen': 0,
#    'Unternehmen': 1,
#    'Erzeugnissen': 0,
#    'Eigenleistungen': 0,
#    'Materialaufwand': 0,
#    'Herstellungskosten': 0,
#    'Personalaufwand': 0,
#    'Erzielung': 0,
#    'Gehälter': 0,
#    'Ausleihungen': 0,
#    'Verlustrechnung': 0,
#    'Jahresfehlbetrag': 0,
#    'Wertpapieren': 0,
#    'GuV': 0},
#   'total_words': 48,
#   'page': 6,
#   'type': 'GuV',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 0,
#   'float_count': 19,
#   'integer_count': 14},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_5_Aktiva': {'word_counts': {'Anteile': 0,
#    'Steuern': 0,
#    'Werten': 0,
#    'Erzeugnisse': 0,
#    'Forderungen': 0,
#    'III': 0,
#    'Bundesbankguthaben': 0,
#    'Immaterielle': 0,
#    'Geschäftsjahr': 0,
#    'Aktivseite': 0,
#    'Rechnungsabgrenzungsposten': 0,
#    'Anlagen': 0,
#    'Kassenbestand': 0,
#    'Sachanlagen': 0,
#    'Umlaufvermögen': 0,
#    'Anlagevermögens': 0,
#    'Rechte': 0,
#    'Vermögensgegenstände': 0,
#    'Vorjahr': 0,
#    'Unterschiedsbetrag': 0,
#    'Hilfs': 0,
#    'Aktiva': 0,
#    'Guthaben': 0,
#    'Kreditinstituten': 0,
#    'Konzessionen': 0,
#    'Vorräte': 0,
#    'Bauten': 0,
#    'Wertpapiere': 0,
#    'Betriebsstoffe': 0,
#    'Firmenwert': 0,
#    'Betriebs': 0,
#    'Anlagevermögen': 0,
#    'Roh': 0,
#    'Finanzanlagen': 0,
#    'Schecks': 0,
#    'Lizenzen': 0,
#    'Grundstücken': 0,
#    'Lieferungen': 0,
#    'Werte': 0,
#    'Anzahlungen': 0,
#    'Geschäftsausstattung': 0,
#    'Rechten': 0,
#    'Bau': 0,
#    'Beteiligungsverhältnis': 0,
#    'Beteiligungen': 0,
#    'Maschinen': 0,
#    'Unternehmen': 1,
#    'Leistungen': 0,
#    'Aktiver': 0,
#    'Vermögensverrechnung': 0,
#    'Aktive': 0,
#    'Grundstücke': 0,
#    'Ausleihungen': 0,
#    'Schutzrechte': 0,
#    'Geschäfts': 1},
#   'total_words': 48,
#   'page': 6,
#   'type': 'Aktiva',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 0,
#   'float_count': 19,
#   'integer_count': 14},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_5_Passiva': {'word_counts': {'Anteile': 0,
#    'Steuern': 0,
#    'Kapitalrücklage': 0,
#    'Passivseite': 0,
#    'III': 0,
#    'Gewinnrücklagen': 0,
#    'Verlustvortrag': 0,
#    'Eigenkapital': 0,
#    'Sicherheit': 0,
#    'Jahresüberschuß': 0,
#    'Rechnungsabgrenzungsposten': 0,
#    'Geschäftsjahr': 0,
#    'Vorjahr': 0,
#    'Verpflichtungen': 0,
#    'Annahme': 0,
#    'Gezeichnetes': 0,
#    'Kreditinstituten': 0,
#    'Verbindlichkeiten': 0,
#    'Rückstellungen': 0,
#    'Pensionen': 0,
#    'Passiva': 0,
#    'Lieferungen': 0,
#    'Steuerrückstellungen': 0,
#    'Rücklagen': 0,
#    'Leistungen': 0,
#    'Anzahlungen': 0,
#    'Anleihen': 0,
#    'Beteiligungsverhältnis': 0,
#    'Unternehmen': 1,
#    'Kapital': 0,
#    'Rücklage': 0,
#    'Bestellungen': 0,
#    'Jahresfehlbetrag': 0,
#    'Rahmen': 1,
#    'Wechsel': 0,
#    'Gewinnvortrag': 0,
#    'Ausstellung': 0,
#    'Passive': 0},
#   'total_words': 48,
#   'page': 6,
#   'type': 'Passiva',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 0,
#   'float_count': 19,
#   'integer_count': 14},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_6_GuV': {'word_counts': {'Steuern': 0,
#    'Einkommen': 0,
#    'Umsatzerlöse': 0,
#    'Abgaben': 0,
#    'Bestands': 0,
#    'Jahresüberschuss': 0,
#    'Umsatz': 0,
#    'Finanzanlagevermögens': 0,
#    'Ertrag': 1,
#    'Geschäftsjahr': 2,
#    'Sachanlagen': 0,
#    'Anlagevermögens': 0,
#    'Vermögensgegenstände': 0,
#    'Vorjahr': 0,
#    'Hilfs': 0,
#    'Aufwendungen': 0,
#    'Kapitalgesellschaft': 0,
#    'Zinsen': 0,
#    'Erhöhung': 0,
#    'Verminderung': 0,
#    'Erträge': 0,
#    'Ergebnis': 0,
#    'Bruttoergebnis': 0,
#    'Löhne': 0,
#    'Altersversorgung': 0,
#    'Wertpapiere': 0,
#    'Vertriebskosten': 0,
#    'Betriebsstoffe': 0,
#    'Unterstützung': 0,
#    'Abschreibungen': 0,
#    'Verwaltungskosten': 0,
#    'Roh': 0,
#    'Finanzanlagen': 0,
#    'Gewinn': 0,
#    'Leistungen': 1,
#    'Umlaufvermögens': 0,
#    'Beteiligungen': 3,
#    'Unternehmen': 7,
#    'Erzeugnissen': 0,
#    'Eigenleistungen': 0,
#    'Materialaufwand': 0,
#    'Herstellungskosten': 0,
#    'Personalaufwand': 0,
#    'Erzielung': 0,
#    'Gehälter': 0,
#    'Ausleihungen': 0,
#    'Verlustrechnung': 0,
#    'Jahresfehlbetrag': 0,
#    'Wertpapieren': 0,
#    'GuV': 0},
#   'total_words': 436,
#   'page': 7,
#   'type': 'GuV',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 5,
#   'float_count': 25,
#   'integer_count': 10},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_6_Aktiva': {'word_counts': {'Anteile': 0,
#    'Steuern': 0,
#    'Werten': 0,
#    'Erzeugnisse': 0,
#    'Forderungen': 0,
#    'III': 0,
#    'Bundesbankguthaben': 0,
#    'Immaterielle': 0,
#    'Geschäftsjahr': 2,
#    'Aktivseite': 0,
#    'Rechnungsabgrenzungsposten': 0,
#    'Anlagen': 0,
#    'Kassenbestand': 0,
#    'Sachanlagen': 0,
#    'Umlaufvermögen': 0,
#    'Anlagevermögens': 0,
#    'Rechte': 1,
#    'Vermögensgegenstände': 0,
#    'Vorjahr': 0,
#    'Unterschiedsbetrag': 0,
#    'Hilfs': 0,
#    'Aktiva': 0,
#    'Guthaben': 0,
#    'Kreditinstituten': 0,
#    'Konzessionen': 0,
#    'Vorräte': 0,
#    'Bauten': 0,
#    'Wertpapiere': 0,
#    'Betriebsstoffe': 0,
#    'Firmenwert': 0,
#    'Betriebs': 0,
#    'Anlagevermögen': 0,
#    'Roh': 0,
#    'Finanzanlagen': 0,
#    'Schecks': 0,
#    'Lizenzen': 0,
#    'Grundstücken': 0,
#    'Lieferungen': 0,
#    'Werte': 0,
#    'Anzahlungen': 0,
#    'Geschäftsausstattung': 0,
#    'Rechten': 0,
#    'Bau': 1,
#    'Beteiligungsverhältnis': 0,
#    'Beteiligungen': 3,
#    'Maschinen': 0,
#    'Unternehmen': 7,
#    'Leistungen': 1,
#    'Aktiver': 0,
#    'Vermögensverrechnung': 0,
#    'Aktive': 0,
#    'Grundstücke': 0,
#    'Ausleihungen': 0,
#    'Schutzrechte': 0,
#    'Geschäfts': 7},
#   'total_words': 436,
#   'page': 7,
#   'type': 'Aktiva',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 5,
#   'float_count': 25,
#   'integer_count': 10},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_6_Passiva': {'word_counts': {'Anteile': 0,
#    'Steuern': 0,
#    'Kapitalrücklage': 0,
#    'Passivseite': 0,
#    'III': 0,
#    'Gewinnrücklagen': 0,
#    'Verlustvortrag': 0,
#    'Eigenkapital': 0,
#    'Sicherheit': 0,
#    'Jahresüberschuß': 0,
#    'Rechnungsabgrenzungsposten': 0,
#    'Geschäftsjahr': 2,
#    'Vorjahr': 0,
#    'Verpflichtungen': 0,
#    'Annahme': 0,
#    'Gezeichnetes': 0,
#    'Kreditinstituten': 0,
#    'Verbindlichkeiten': 0,
#    'Rückstellungen': 0,
#    'Pensionen': 0,
#    'Passiva': 0,
#    'Lieferungen': 0,
#    'Steuerrückstellungen': 0,
#    'Rücklagen': 0,
#    'Leistungen': 1,
#    'Anzahlungen': 0,
#    'Anleihen': 0,
#    'Beteiligungsverhältnis': 0,
#    'Unternehmen': 7,
#    'Kapital': 2,
#    'Rücklage': 0,
#    'Bestellungen': 0,
#    'Jahresfehlbetrag': 0,
#    'Rahmen': 3,
#    'Wechsel': 0,
#    'Gewinnvortrag': 0,
#    'Ausstellung': 0,
#    'Passive': 0},
#   'total_words': 436,
#   'page': 7,
#   'type': 'Passiva',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 5,
#   'float_count': 25,
#   'integer_count': 10},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_7_GuV': {'word_counts': {'Steuern': 0,
#    'Einkommen': 0,
#    'Umsatzerlöse': 0,
#    'Abgaben': 0,
#    'Bestands': 1,
#    'Jahresüberschuss': 0,
#    'Umsatz': 0,
#    'Finanzanlagevermögens': 0,
#    'Ertrag': 1,
#    'Geschäftsjahr': 0,
#    'Sachanlagen': 0,
#    'Anlagevermögens': 0,
#    'Vermögensgegenstände': 0,
#    'Vorjahr': 0,
#    'Hilfs': 0,
#    'Aufwendungen': 0,
#    'Kapitalgesellschaft': 0,
#    'Zinsen': 1,
#    'Erhöhung': 0,
#    'Verminderung': 0,
#    'Erträge': 0,
#    'Ergebnis': 1,
#    'Bruttoergebnis': 0,
#    'Löhne': 0,
#    'Altersversorgung': 0,
#    'Wertpapiere': 0,
#    'Vertriebskosten': 0,
#    'Betriebsstoffe': 0,
#    'Unterstützung': 1,
#    'Abschreibungen': 0,
#    'Verwaltungskosten': 0,
#    'Roh': 1,
#    'Finanzanlagen': 0,
#    'Gewinn': 0,
#    'Leistungen': 0,
#    'Umlaufvermögens': 0,
#    'Beteiligungen': 0,
#    'Unternehmen': 0,
#    'Erzeugnissen': 0,
#    'Eigenleistungen': 0,
#    'Materialaufwand': 0,
#    'Herstellungskosten': 0,
#    'Personalaufwand': 0,
#    'Erzielung': 0,
#    'Gehälter': 0,
#    'Ausleihungen': 0,
#    'Verlustrechnung': 0,
#    'Jahresfehlbetrag': 0,
#    'Wertpapieren': 0,
#    'GuV': 0},
#   'total_words': 512,
#   'page': 8,
#   'type': 'GuV',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 2,
#   'float_count': 24,
#   'integer_count': 16},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_7_Aktiva': {'word_counts': {'Anteile': 0,
#    'Steuern': 0,
#    'Werten': 1,
#    'Erzeugnisse': 0,
#    'Forderungen': 2,
#    'III': 0,
#    'Bundesbankguthaben': 0,
#    'Immaterielle': 0,
#    'Geschäftsjahr': 0,
#    'Aktivseite': 0,
#    'Rechnungsabgrenzungsposten': 0,
#    'Anlagen': 1,
#    'Kassenbestand': 0,
#    'Sachanlagen': 0,
#    'Umlaufvermögen': 0,
#    'Anlagevermögens': 0,
#    'Rechte': 0,
#    'Vermögensgegenstände': 0,
#    'Vorjahr': 0,
#    'Unterschiedsbetrag': 0,
#    'Hilfs': 0,
#    'Aktiva': 0,
#    'Guthaben': 0,
#    'Kreditinstituten': 0,
#    'Konzessionen': 0,
#    'Vorräte': 0,
#    'Bauten': 0,
#    'Wertpapiere': 0,
#    'Betriebsstoffe': 0,
#    'Firmenwert': 0,
#    'Betriebs': 0,
#    'Anlagevermögen': 0,
#    'Roh': 1,
#    'Finanzanlagen': 0,
#    'Schecks': 0,
#    'Lizenzen': 0,
#    'Grundstücken': 0,
#    'Lieferungen': 0,
#    'Werte': 1,
#    'Anzahlungen': 0,
#    'Geschäftsausstattung': 0,
#    'Rechten': 0,
#    'Bau': 4,
#    'Beteiligungsverhältnis': 0,
#    'Beteiligungen': 0,
#    'Maschinen': 0,
#    'Unternehmen': 0,
#    'Leistungen': 0,
#    'Aktiver': 0,
#    'Vermögensverrechnung': 0,
#    'Aktive': 0,
#    'Grundstücke': 0,
#    'Ausleihungen': 0,
#    'Schutzrechte': 0,
#    'Geschäfts': 0},
#   'total_words': 512,
#   'page': 8,
#   'type': 'Aktiva',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 2,
#   'float_count': 24,
#   'integer_count': 16},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_7_Passiva': {'word_counts': {'Anteile': 0,
#    'Steuern': 0,
#    'Kapitalrücklage': 0,
#    'Passivseite': 0,
#    'III': 0,
#    'Gewinnrücklagen': 0,
#    'Verlustvortrag': 0,
#    'Eigenkapital': 2,
#    'Sicherheit': 1,
#    'Jahresüberschuß': 0,
#    'Rechnungsabgrenzungsposten': 0,
#    'Geschäftsjahr': 0,
#    'Vorjahr': 0,
#    'Verpflichtungen': 0,
#    'Annahme': 1,
#    'Gezeichnetes': 0,
#    'Kreditinstituten': 0,
#    'Verbindlichkeiten': 0,
#    'Rückstellungen': 0,
#    'Pensionen': 0,
#    'Passiva': 0,
#    'Lieferungen': 0,
#    'Steuerrückstellungen': 0,
#    'Rücklagen': 0,
#    'Leistungen': 0,
#    'Anzahlungen': 0,
#    'Anleihen': 0,
#    'Beteiligungsverhältnis': 0,
#    'Unternehmen': 0,
#    'Kapital': 4,
#    'Rücklage': 0,
#    'Bestellungen': 0,
#    'Jahresfehlbetrag': 0,
#    'Rahmen': 0,
#    'Wechsel': 0,
#    'Gewinnvortrag': 0,
#    'Ausstellung': 0,
#    'Passive': 0},
#   'total_words': 512,
#   'page': 8,
#   'type': 'Passiva',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 2,
#   'float_count': 24,
#   'integer_count': 16},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_8_GuV': {'word_counts': {'Steuern': 0,
#    'Einkommen': 0,
#    'Umsatzerlöse': 0,
#    'Abgaben': 0,
#    'Bestands': 0,
#    'Jahresüberschuss': 0,
#    'Umsatz': 0,
#    'Finanzanlagevermögens': 0,
#    'Ertrag': 1,
#    'Geschäftsjahr': 0,
#    'Sachanlagen': 0,
#    'Anlagevermögens': 0,
#    'Vermögensgegenstände': 0,
#    'Vorjahr': 0,
#    'Hilfs': 0,
#    'Aufwendungen': 0,
#    'Kapitalgesellschaft': 0,
#    'Zinsen': 0,
#    'Erhöhung': 0,
#    'Verminderung': 0,
#    'Erträge': 0,
#    'Ergebnis': 0,
#    'Bruttoergebnis': 0,
#    'Löhne': 0,
#    'Altersversorgung': 0,
#    'Wertpapiere': 0,
#    'Vertriebskosten': 0,
#    'Betriebsstoffe': 0,
#    'Unterstützung': 0,
#    'Abschreibungen': 0,
#    'Verwaltungskosten': 0,
#    'Roh': 0,
#    'Finanzanlagen': 0,
#    'Gewinn': 0,
#    'Leistungen': 0,
#    'Umlaufvermögens': 0,
#    'Beteiligungen': 0,
#    'Unternehmen': 0,
#    'Erzeugnissen': 0,
#    'Eigenleistungen': 0,
#    'Materialaufwand': 0,
#    'Herstellungskosten': 0,
#    'Personalaufwand': 0,
#    'Erzielung': 0,
#    'Gehälter': 0,
#    'Ausleihungen': 0,
#    'Verlustrechnung': 0,
#    'Jahresfehlbetrag': 0,
#    'Wertpapieren': 0,
#    'GuV': 0},
#   'total_words': 577,
#   'page': 9,
#   'type': 'GuV',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 4,
#   'float_count': 24,
#   'integer_count': 14},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_8_Aktiva': {'word_counts': {'Anteile': 1,
#    'Steuern': 0,
#    'Werten': 0,
#    'Erzeugnisse': 0,
#    'Forderungen': 0,
#    'III': 0,
#    'Bundesbankguthaben': 0,
#    'Immaterielle': 0,
#    'Geschäftsjahr': 0,
#    'Aktivseite': 0,
#    'Rechnungsabgrenzungsposten': 0,
#    'Anlagen': 5,
#    'Kassenbestand': 0,
#    'Sachanlagen': 0,
#    'Umlaufvermögen': 0,
#    'Anlagevermögens': 0,
#    'Rechte': 0,
#    'Vermögensgegenstände': 0,
#    'Vorjahr': 0,
#    'Unterschiedsbetrag': 0,
#    'Hilfs': 0,
#    'Aktiva': 0,
#    'Guthaben': 0,
#    'Kreditinstituten': 0,
#    'Konzessionen': 0,
#    'Vorräte': 0,
#    'Bauten': 0,
#    'Wertpapiere': 0,
#    'Betriebsstoffe': 0,
#    'Firmenwert': 0,
#    'Betriebs': 0,
#    'Anlagevermögen': 0,
#    'Roh': 0,
#    'Finanzanlagen': 0,
#    'Schecks': 0,
#    'Lizenzen': 0,
#    'Grundstücken': 0,
#    'Lieferungen': 0,
#    'Werte': 0,
#    'Anzahlungen': 0,
#    'Geschäftsausstattung': 0,
#    'Rechten': 0,
#    'Bau': 8,
#    'Beteiligungsverhältnis': 0,
#    'Beteiligungen': 0,
#    'Maschinen': 0,
#    'Unternehmen': 0,
#    'Leistungen': 0,
#    'Aktiver': 0,
#    'Vermögensverrechnung': 0,
#    'Aktive': 0,
#    'Grundstücke': 0,
#    'Ausleihungen': 0,
#    'Schutzrechte': 0,
#    'Geschäfts': 0},
#   'total_words': 577,
#   'page': 9,
#   'type': 'Aktiva',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 4,
#   'float_count': 24,
#   'integer_count': 14},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_8_Passiva': {'word_counts': {'Anteile': 1,
#    'Steuern': 0,
#    'Kapitalrücklage': 0,
#    'Passivseite': 0,
#    'III': 0,
#    'Gewinnrücklagen': 0,
#    'Verlustvortrag': 0,
#    'Eigenkapital': 0,
#    'Sicherheit': 0,
#    'Jahresüberschuß': 0,
#    'Rechnungsabgrenzungsposten': 0,
#    'Geschäftsjahr': 0,
#    'Vorjahr': 0,
#    'Verpflichtungen': 0,
#    'Annahme': 0,
#    'Gezeichnetes': 0,
#    'Kreditinstituten': 0,
#    'Verbindlichkeiten': 0,
#    'Rückstellungen': 0,
#    'Pensionen': 0,
#    'Passiva': 0,
#    'Lieferungen': 0,
#    'Steuerrückstellungen': 0,
#    'Rücklagen': 0,
#    'Leistungen': 0,
#    'Anzahlungen': 0,
#    'Anleihen': 0,
#    'Beteiligungsverhältnis': 0,
#    'Unternehmen': 0,
#    'Kapital': 0,
#    'Rücklage': 0,
#    'Bestellungen': 0,
#    'Jahresfehlbetrag': 0,
#    'Rahmen': 1,
#    'Wechsel': 2,
#    'Gewinnvortrag': 0,
#    'Ausstellung': 0,
#    'Passive': 0},
#   'total_words': 577,
#   'page': 9,
#   'type': 'Passiva',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 4,
#   'float_count': 24,
#   'integer_count': 14},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_9_GuV': {'word_counts': {'Steuern': 0,
#    'Einkommen': 0,
#    'Umsatzerlöse': 0,
#    'Abgaben': 0,
#    'Bestands': 0,
#    'Jahresüberschuss': 0,
#    'Umsatz': 0,
#    'Finanzanlagevermögens': 0,
#    'Ertrag': 5,
#    'Geschäftsjahr': 0,
#    'Sachanlagen': 0,
#    'Anlagevermögens': 0,
#    'Vermögensgegenstände': 0,
#    'Vorjahr': 0,
#    'Hilfs': 0,
#    'Aufwendungen': 0,
#    'Kapitalgesellschaft': 0,
#    'Zinsen': 0,
#    'Erhöhung': 0,
#    'Verminderung': 0,
#    'Erträge': 0,
#    'Ergebnis': 1,
#    'Bruttoergebnis': 0,
#    'Löhne': 0,
#    'Altersversorgung': 0,
#    'Wertpapiere': 0,
#    'Vertriebskosten': 0,
#    'Betriebsstoffe': 0,
#    'Unterstützung': 0,
#    'Abschreibungen': 0,
#    'Verwaltungskosten': 0,
#    'Roh': 0,
#    'Finanzanlagen': 0,
#    'Gewinn': 0,
#    'Leistungen': 0,
#    'Umlaufvermögens': 0,
#    'Beteiligungen': 1,
#    'Unternehmen': 1,
#    'Erzeugnissen': 0,
#    'Eigenleistungen': 0,
#    'Materialaufwand': 0,
#    'Herstellungskosten': 0,
#    'Personalaufwand': 0,
#    'Erzielung': 0,
#    'Gehälter': 0,
#    'Ausleihungen': 0,
#    'Verlustrechnung': 0,
#    'Jahresfehlbetrag': 0,
#    'Wertpapieren': 0,
#    'GuV': 0},
#   'total_words': 388,
#   'page': 10,
#   'type': 'GuV',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 9,
#   'float_count': 23,
#   'integer_count': 4},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_9_Aktiva': {'word_counts': {'Anteile': 0,
#    'Steuern': 0,
#    'Werten': 0,
#    'Erzeugnisse': 0,
#    'Forderungen': 0,
#    'III': 0,
#    'Bundesbankguthaben': 0,
#    'Immaterielle': 0,
#    'Geschäftsjahr': 0,
#    'Aktivseite': 0,
#    'Rechnungsabgrenzungsposten': 0,
#    'Anlagen': 0,
#    'Kassenbestand': 0,
#    'Sachanlagen': 0,
#    'Umlaufvermögen': 0,
#    'Anlagevermögens': 0,
#    'Rechte': 0,
#    'Vermögensgegenstände': 0,
#    'Vorjahr': 0,
#    'Unterschiedsbetrag': 0,
#    'Hilfs': 0,
#    'Aktiva': 0,
#    'Guthaben': 0,
#    'Kreditinstituten': 0,
#    'Konzessionen': 0,
#    'Vorräte': 0,
#    'Bauten': 0,
#    'Wertpapiere': 0,
#    'Betriebsstoffe': 0,
#    'Firmenwert': 0,
#    'Betriebs': 0,
#    'Anlagevermögen': 0,
#    'Roh': 0,
#    'Finanzanlagen': 0,
#    'Schecks': 0,
#    'Lizenzen': 0,
#    'Grundstücken': 0,
#    'Lieferungen': 0,
#    'Werte': 0,
#    'Anzahlungen': 0,
#    'Geschäftsausstattung': 0,
#    'Rechten': 0,
#    'Bau': 6,
#    'Beteiligungsverhältnis': 0,
#    'Beteiligungen': 1,
#    'Maschinen': 0,
#    'Unternehmen': 1,
#    'Leistungen': 0,
#    'Aktiver': 0,
#    'Vermögensverrechnung': 0,
#    'Aktive': 0,
#    'Grundstücke': 0,
#    'Ausleihungen': 0,
#    'Schutzrechte': 0,
#    'Geschäfts': 1},
#   'total_words': 388,
#   'page': 10,
#   'type': 'Aktiva',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 9,
#   'float_count': 23,
#   'integer_count': 4},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_9_Passiva': {'word_counts': {'Anteile': 0,
#    'Steuern': 0,
#    'Kapitalrücklage': 1,
#    'Passivseite': 0,
#    'III': 0,
#    'Gewinnrücklagen': 0,
#    'Verlustvortrag': 0,
#    'Eigenkapital': 3,
#    'Sicherheit': 0,
#    'Jahresüberschuß': 0,
#    'Rechnungsabgrenzungsposten': 0,
#    'Geschäftsjahr': 0,
#    'Vorjahr': 0,
#    'Verpflichtungen': 0,
#    'Annahme': 0,
#    'Gezeichnetes': 0,
#    'Kreditinstituten': 0,
#    'Verbindlichkeiten': 0,
#    'Rückstellungen': 0,
#    'Pensionen': 0,
#    'Passiva': 0,
#    'Lieferungen': 0,
#    'Steuerrückstellungen': 0,
#    'Rücklagen': 0,
#    'Leistungen': 0,
#    'Anzahlungen': 0,
#    'Anleihen': 0,
#    'Beteiligungsverhältnis': 0,
#    'Unternehmen': 1,
#    'Kapital': 6,
#    'Rücklage': 1,
#    'Bestellungen': 0,
#    'Jahresfehlbetrag': 0,
#    'Rahmen': 0,
#    'Wechsel': 0,
#    'Gewinnvortrag': 0,
#    'Ausstellung': 0,
#    'Passive': 0},
#   'total_words': 388,
#   'page': 10,
#   'type': 'Passiva',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 9,
#   'float_count': 23,
#   'integer_count': 4},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_10_GuV': {'word_counts': {'Steuern': 2,
#    'Einkommen': 0,
#    'Umsatzerlöse': 2,
#    'Abgaben': 0,
#    'Bestands': 0,
#    'Jahresüberschuss': 1,
#    'Umsatz': 2,
#    'Finanzanlagevermögens': 0,
#    'Ertrag': 1,
#    'Geschäftsjahr': 2,
#    'Sachanlagen': 0,
#    'Anlagevermögens': 1,
#    'Vermögensgegenstände': 1,
#    'Vorjahr': 6,
#    'Hilfs': 0,
#    'Aufwendungen': 1,
#    'Kapitalgesellschaft': 0,
#    'Zinsen': 0,
#    'Erhöhung': 0,
#    'Verminderung': 0,
#    'Erträge': 3,
#    'Ergebnis': 7,
#    'Bruttoergebnis': 0,
#    'Löhne': 0,
#    'Altersversorgung': 0,
#    'Wertpapiere': 0,
#    'Vertriebskosten': 0,
#    'Betriebsstoffe': 0,
#    'Unterstützung': 0,
#    'Abschreibungen': 3,
#    'Verwaltungskosten': 0,
#    'Roh': 0,
#    'Finanzanlagen': 0,
#    'Gewinn': 0,
#    'Leistungen': 0,
#    'Umlaufvermögens': 0,
#    'Beteiligungen': 0,
#    'Unternehmen': 1,
#    'Erzeugnissen': 0,
#    'Eigenleistungen': 0,
#    'Materialaufwand': 0,
#    'Herstellungskosten': 0,
#    'Personalaufwand': 2,
#    'Erzielung': 0,
#    'Gehälter': 0,
#    'Ausleihungen': 0,
#    'Verlustrechnung': 0,
#    'Jahresfehlbetrag': 0,
#    'Wertpapieren': 0,
#    'GuV': 0},
#   'total_words': 315,
#   'page': 11,
#   'type': 'GuV',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 4,
#   'float_count': 50,
#   'integer_count': 7},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_10_Aktiva': {'word_counts': {'Anteile': 0,
#    'Steuern': 2,
#    'Werten': 0,
#    'Erzeugnisse': 0,
#    'Forderungen': 0,
#    'III': 0,
#    'Bundesbankguthaben': 0,
#    'Immaterielle': 1,
#    'Geschäftsjahr': 2,
#    'Aktivseite': 0,
#    'Rechnungsabgrenzungsposten': 0,
#    'Anlagen': 0,
#    'Kassenbestand': 0,
#    'Sachanlagen': 0,
#    'Umlaufvermögen': 0,
#    'Anlagevermögens': 1,
#    'Rechte': 0,
#    'Vermögensgegenstände': 1,
#    'Vorjahr': 6,
#    'Unterschiedsbetrag': 0,
#    'Hilfs': 0,
#    'Aktiva': 0,
#    'Guthaben': 0,
#    'Kreditinstituten': 0,
#    'Konzessionen': 0,
#    'Vorräte': 0,
#    'Bauten': 0,
#    'Wertpapiere': 0,
#    'Betriebsstoffe': 0,
#    'Firmenwert': 0,
#    'Betriebs': 0,
#    'Anlagevermögen': 2,
#    'Roh': 0,
#    'Finanzanlagen': 0,
#    'Schecks': 0,
#    'Lizenzen': 0,
#    'Grundstücken': 0,
#    'Lieferungen': 0,
#    'Werte': 0,
#    'Anzahlungen': 0,
#    'Geschäftsausstattung': 0,
#    'Rechten': 0,
#    'Bau': 1,
#    'Beteiligungsverhältnis': 0,
#    'Beteiligungen': 0,
#    'Maschinen': 0,
#    'Unternehmen': 1,
#    'Leistungen': 0,
#    'Aktiver': 0,
#    'Vermögensverrechnung': 0,
#    'Aktive': 0,
#    'Grundstücke': 0,
#    'Ausleihungen': 0,
#    'Schutzrechte': 0,
#    'Geschäfts': 3},
#   'total_words': 315,
#   'page': 11,
#   'type': 'Aktiva',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 4,
#   'float_count': 50,
#   'integer_count': 7},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_10_Passiva': {'word_counts': {'Anteile': 0,
#    'Steuern': 2,
#    'Kapitalrücklage': 0,
#    'Passivseite': 0,
#    'III': 0,
#    'Gewinnrücklagen': 0,
#    'Verlustvortrag': 0,
#    'Eigenkapital': 0,
#    'Sicherheit': 0,
#    'Jahresüberschuß': 0,
#    'Rechnungsabgrenzungsposten': 0,
#    'Geschäftsjahr': 2,
#    'Vorjahr': 6,
#    'Verpflichtungen': 0,
#    'Annahme': 0,
#    'Gezeichnetes': 0,
#    'Kreditinstituten': 0,
#    'Verbindlichkeiten': 0,
#    'Rückstellungen': 0,
#    'Pensionen': 0,
#    'Passiva': 0,
#    'Lieferungen': 0,
#    'Steuerrückstellungen': 0,
#    'Rücklagen': 0,
#    'Leistungen': 0,
#    'Anzahlungen': 0,
#    'Anleihen': 0,
#    'Beteiligungsverhältnis': 0,
#    'Unternehmen': 1,
#    'Kapital': 0,
#    'Rücklage': 0,
#    'Bestellungen': 0,
#    'Jahresfehlbetrag': 0,
#    'Rahmen': 1,
#    'Wechsel': 0,
#    'Gewinnvortrag': 0,
#    'Ausstellung': 0,
#    'Passive': 0},
#   'total_words': 315,
#   'page': 11,
#   'type': 'Passiva',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 4,
#   'float_count': 50,
#   'integer_count': 7},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_11_GuV': {'word_counts': {'Steuern': 0,
#    'Einkommen': 0,
#    'Umsatzerlöse': 0,
#    'Abgaben': 0,
#    'Bestands': 0,
#    'Jahresüberschuss': 0,
#    'Umsatz': 0,
#    'Finanzanlagevermögens': 0,
#    'Ertrag': 1,
#    'Geschäftsjahr': 0,
#    'Sachanlagen': 0,
#    'Anlagevermögens': 0,
#    'Vermögensgegenstände': 0,
#    'Vorjahr': 8,
#    'Hilfs': 0,
#    'Aufwendungen': 3,
#    'Kapitalgesellschaft': 0,
#    'Zinsen': 4,
#    'Erhöhung': 1,
#    'Verminderung': 0,
#    'Erträge': 3,
#    'Ergebnis': 7,
#    'Bruttoergebnis': 0,
#    'Löhne': 0,
#    'Altersversorgung': 0,
#    'Wertpapiere': 0,
#    'Vertriebskosten': 0,
#    'Betriebsstoffe': 0,
#    'Unterstützung': 0,
#    'Abschreibungen': 0,
#    'Verwaltungskosten': 0,
#    'Roh': 0,
#    'Finanzanlagen': 0,
#    'Gewinn': 1,
#    'Leistungen': 1,
#    'Umlaufvermögens': 0,
#    'Beteiligungen': 0,
#    'Unternehmen': 1,
#    'Erzeugnissen': 0,
#    'Eigenleistungen': 0,
#    'Materialaufwand': 0,
#    'Herstellungskosten': 0,
#    'Personalaufwand': 0,
#    'Erzielung': 0,
#    'Gehälter': 0,
#    'Ausleihungen': 0,
#    'Verlustrechnung': 0,
#    'Jahresfehlbetrag': 0,
#    'Wertpapieren': 0,
#    'GuV': 0},
#   'total_words': 338,
#   'page': 12,
#   'type': 'GuV',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 2,
#   'float_count': 41,
#   'integer_count': 2},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_11_Aktiva': {'word_counts': {'Anteile': 1,
#    'Steuern': 0,
#    'Werten': 0,
#    'Erzeugnisse': 0,
#    'Forderungen': 2,
#    'III': 0,
#    'Bundesbankguthaben': 0,
#    'Immaterielle': 0,
#    'Geschäftsjahr': 0,
#    'Aktivseite': 0,
#    'Rechnungsabgrenzungsposten': 1,
#    'Anlagen': 0,
#    'Kassenbestand': 0,
#    'Sachanlagen': 0,
#    'Umlaufvermögen': 2,
#    'Anlagevermögens': 0,
#    'Rechte': 0,
#    'Vermögensgegenstände': 0,
#    'Vorjahr': 8,
#    'Unterschiedsbetrag': 0,
#    'Hilfs': 0,
#    'Aktiva': 1,
#    'Guthaben': 1,
#    'Kreditinstituten': 1,
#    'Konzessionen': 0,
#    'Vorräte': 0,
#    'Bauten': 0,
#    'Wertpapiere': 0,
#    'Betriebsstoffe': 0,
#    'Firmenwert': 0,
#    'Betriebs': 0,
#    'Anlagevermögen': 2,
#    'Roh': 0,
#    'Finanzanlagen': 0,
#    'Schecks': 0,
#    'Lizenzen': 0,
#    'Grundstücken': 0,
#    'Lieferungen': 0,
#    'Werte': 0,
#    'Anzahlungen': 0,
#    'Geschäftsausstattung': 0,
#    'Rechten': 0,
#    'Bau': 0,
#    'Beteiligungsverhältnis': 0,
#    'Beteiligungen': 0,
#    'Maschinen': 0,
#    'Unternehmen': 1,
#    'Leistungen': 1,
#    'Aktiver': 0,
#    'Vermögensverrechnung': 0,
#    'Aktive': 0,
#    'Grundstücke': 0,
#    'Ausleihungen': 0,
#    'Schutzrechte': 0,
#    'Geschäfts': 0},
#   'total_words': 338,
#   'page': 12,
#   'type': 'Aktiva',
#   'file_path': '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf',
#   'date_count': 2,
#   'float_count': 41,
#   'integer_count': 2},
#  '/pvc/Geschaeftsberichte/Berlin Energie und Netzholding/Jahresabschluss-BEN-GmbH-2023.pdf_11_Passiva': {'word_counts': {'Anteile': 1,
#    'Steuern': 0,
#    'Kapitalrücklage': 1,
#    'Passivseite': 0,
#    'III': 0,
#    'Gewinnrücklagen': 0,
#    'Verlustvortrag': 0,
#    'Eigenkapital': 1,
#    'Sicherheit': 0,
#    'Jahresüberschuß': 0,
#    'Rechnungsabgrenzungsposten': 1,
#    'Geschäftsjahr': 0,
#    'Vorjahr': 8,
#    'Verpflichtungen': 0,
# ...
#    'Sachanlagen': 0,
#    'Umlaufvermögen': 0,
#    'Anlagevermögens': 0,
#    'Rechte': 0,
#    'Vermögensgegenstände': 0,
#    'Vorjahr': 0,
#    'Unterschiedsbetrag': 0,
#    'Hilfs': 0,
#    'Aktiva': 0,
#    'Guthaben': 0,
#    'Kreditinstituten': 0,
#    'Konzessionen': 0,
#    'Vorräte': 0,
#    'Bauten': 0,
#    'Wertpapiere': 0,
#    'Betriebsstoffe': 0,
#    'Firmenwert': 0,
#    'Betriebs': 0,
#    'Anlagevermögen': 0,
#    'Roh': 0,
#    'Finanzanlagen': 0,
#    'Schecks': 0,
#    'Lizenzen': 0,
#    'Grundstücken': 0,
#    'Lieferungen': 0,
#    'Werte': 0,
#    'Anzahlungen': 0,
#    'Geschäftsausstattung': 0,
#    'Rechten': 0,
#    'Bau': 0,
#    'Beteiligungsverhältnis': 0,
#    'Beteiligungen': 0,
#    'Maschinen': 0,
#    'Unternehmen': 0,
#    'Leistungen': 0,
#    'Aktiver': 0,
#    'Vermögensverrechnung': 0,
#    'Aktive': 0,
#    'Grundstücke': 0,
#    'Ausleihungen': 0,
#    'Schutzrechte': 0,
#    'Geschäfts': 0},
#   'total_words': 310,
#   'page': 28,
#   'type': 'Aktiva',
#   'file_path': '/pvc/Geschaeftsberichte/degewo AG/212131_degewo_2022_Konzernlagebericht_Konzernabschluss.pdf',
#   'date_count': 0,
#   'float_count': 239,
#   'integer_count': 65},
#  '/pvc/Geschaeftsberichte/degewo AG/212131_degewo_2022_Konzernlagebericht_Konzernabschluss.pdf_27_Passiva': {'word_counts': {'Anteile': 0,
#    'Steuern': 0,
#    'Kapitalrücklage': 0,
#    'Passivseite': 0,
#    'III': 0,
#    'Gewinnrücklagen': 0,
#    'Verlustvortrag': 0,
#    'Eigenkapital': 0,
#    'Sicherheit': 0,
#    'Jahresüberschuß': 0,
#    'Rechnungsabgrenzungsposten': 0,
#    'Geschäftsjahr': 0,
#    'Vorjahr': 0,
#    'Verpflichtungen': 0,
#    'Annahme': 0,
#    'Gezeichnetes': 0,
#    'Kreditinstituten': 0,
#    'Verbindlichkeiten': 0,
#    'Rückstellungen': 0,
#    'Pensionen': 0,
#    'Passiva': 0,
#    'Lieferungen': 0,
#    'Steuerrückstellungen': 0,
#    'Rücklagen': 0,
#    'Leistungen': 0,
#    'Anzahlungen': 0,
#    'Anleihen': 0,
#    'Beteiligungsverhältnis': 0,
#    'Unternehmen': 0,
#    'Kapital': 0,
#    'Rücklage': 0,
#    'Bestellungen': 0,
#    'Jahresfehlbetrag': 0,
#    'Rahmen': 0,
#    'Wechsel': 0,
#    'Gewinnvortrag': 0,
#    'Ausstellung': 0,
#    'Passive': 0},
#   'total_words': 310,
#   'page': 28,
#   'type': 'Passiva',
#   'file_path': '/pvc/Geschaeftsberichte/degewo AG/212131_degewo_2022_Konzernlagebericht_Konzernabschluss.pdf',
#   'date_count': 0,
#   'float_count': 239,
#   'integer_count': 65},
#  '/pvc/Geschaeftsberichte/degewo AG/212131_degewo_2022_Konzernlagebericht_Konzernabschluss.pdf_28_GuV': {'word_counts': {'Steuern': 0,
#    'Einkommen': 0,
#    'Umsatzerlöse': 0,
#    'Abgaben': 0,
#    'Bestands': 0,
#    'Jahresüberschuss': 0,
#    'Umsatz': 0,
#    'Finanzanlagevermögens': 0,
#    'Ertrag': 0,
#    'Geschäftsjahr': 1,
#    'Sachanlagen': 0,
#    'Anlagevermögens': 0,
#    'Vermögensgegenstände': 0,
#    'Vorjahr': 0,
#    'Hilfs': 0,
#    'Aufwendungen': 0,
#    'Kapitalgesellschaft': 0,
#    'Zinsen': 0,
#    'Erhöhung': 0,
#    'Verminderung': 0,
#    'Erträge': 0,
#    'Ergebnis': 0,
#    'Bruttoergebnis': 0,
#    'Löhne': 0,
#    'Altersversorgung': 0,
#    'Wertpapiere': 0,
#    'Vertriebskosten': 0,
#    'Betriebsstoffe': 0,
#    'Unterstützung': 0,
#    'Abschreibungen': 0,
#    'Verwaltungskosten': 0,
#    'Roh': 0,
#    'Finanzanlagen': 0,
#    'Gewinn': 0,
#    'Leistungen': 0,
#    'Umlaufvermögens': 0,
#    'Beteiligungen': 0,
#    'Unternehmen': 0,
#    'Erzeugnissen': 0,
#    'Eigenleistungen': 0,
#    'Materialaufwand': 0,
#    'Herstellungskosten': 0,
#    'Personalaufwand': 0,
#    'Erzielung': 0,
#    'Gehälter': 0,
#    'Ausleihungen': 0,
#    'Verlustrechnung': 0,
#    'Jahresfehlbetrag': 0,
#    'Wertpapieren': 0,
#    'GuV': 0},
#   'total_words': 15,
#   'page': 29,
#   'type': 'GuV',
#   'file_path': '/pvc/Geschaeftsberichte/degewo AG/212131_degewo_2022_Konzernlagebericht_Konzernabschluss.pdf',
#   'date_count': 0,
#   'float_count': 6,
#   'integer_count': 3},
#  '/pvc/Geschaeftsberichte/degewo AG/212131_degewo_2022_Konzernlagebericht_Konzernabschluss.pdf_28_Aktiva': {'word_counts': {'Anteile': 0,
#    'Steuern': 0,
#    'Werten': 0,
#    'Erzeugnisse': 0,
#    'Forderungen': 0,
#    'III': 0,
#    'Bundesbankguthaben': 0,
#    'Immaterielle': 0,
#    'Geschäftsjahr': 1,
#    'Aktivseite': 0,
#    'Rechnungsabgrenzungsposten': 0,
#    'Anlagen': 0,
#    'Kassenbestand': 0,
#    'Sachanlagen': 0,
#    'Umlaufvermögen': 0,
#    'Anlagevermögens': 0,
#    'Rechte': 0,
#    'Vermögensgegenstände': 0,
#    'Vorjahr': 0,
#    'Unterschiedsbetrag': 0,
#    'Hilfs': 0,
#    'Aktiva': 0,
#    'Guthaben': 0,
#    'Kreditinstituten': 0,
#    'Konzessionen': 0,
#    'Vorräte': 0,
#    'Bauten': 0,
#    'Wertpapiere': 0,
#    'Betriebsstoffe': 0,
#    'Firmenwert': 0,
#    'Betriebs': 0,
#    'Anlagevermögen': 0,
#    'Roh': 0,
#    'Finanzanlagen': 0,
#    'Schecks': 0,
#    'Lizenzen': 0,
#    'Grundstücken': 0,
#    'Lieferungen': 0,
#    'Werte': 0,
#    'Anzahlungen': 0,
#    'Geschäftsausstattung': 0,
#    'Rechten': 0,
#    'Bau': 0,
#    'Beteiligungsverhältnis': 0,
#    'Beteiligungen': 0,
#    'Maschinen': 0,
#    'Unternehmen': 0,
#    'Leistungen': 0,
#    'Aktiver': 0,
#    'Vermögensverrechnung': 0,
#    'Aktive': 0,
#    'Grundstücke': 0,
#    'Ausleihungen': 0,
#    'Schutzrechte': 0,
#    'Geschäfts': 1},
#   'total_words': 15,
#   'page': 29,
#   'type': 'Aktiva',
#   'file_path': '/pvc/Geschaeftsberichte/degewo AG/212131_degewo_2022_Konzernlagebericht_Konzernabschluss.pdf',
#   'date_count': 0,
#   'float_count': 6,
#   'integer_count': 3},
#  '/pvc/Geschaeftsberichte/degewo AG/212131_degewo_2022_Konzernlagebericht_Konzernabschluss.pdf_28_Passiva': {'word_counts': {'Anteile': 0,
#    'Steuern': 0,
#    'Kapitalrücklage': 0,
#    'Passivseite': 0,
#    'III': 0,
#    'Gewinnrücklagen': 0,
#    'Verlustvortrag': 0,
#    'Eigenkapital': 0,
#    'Sicherheit': 0,
#    'Jahresüberschuß': 0,
#    'Rechnungsabgrenzungsposten': 0,
#    'Geschäftsjahr': 1,
#    'Vorjahr': 0,
#    'Verpflichtungen': 0,
#    'Annahme': 0,
#    'Gezeichnetes': 0,
#    'Kreditinstituten': 0,
#    'Verbindlichkeiten': 0,
#    'Rückstellungen': 0,
#    'Pensionen': 0,
#    'Passiva': 0,
#    'Lieferungen': 0,
#    'Steuerrückstellungen': 0,
#    'Rücklagen': 0,
#    'Leistungen': 0,
#    'Anzahlungen': 0,
#    'Anleihen': 0,
#    'Beteiligungsverhältnis': 0,
#    'Unternehmen': 0,
#    'Kapital': 0,
#    'Rücklage': 0,
#    'Bestellungen': 0,
#    'Jahresfehlbetrag': 0,
#    'Rahmen': 0,
#    'Wechsel': 0,
#    'Gewinnvortrag': 0,
#    'Ausstellung': 0,
#    'Passive': 0},
#   'total_words': 15,
#   'page': 29,
#   'type': 'Passiva',
#   'file_path': '/pvc/Geschaeftsberichte/degewo AG/212131_degewo_2022_Konzernlagebericht_Konzernabschluss.pdf',
#   'date_count': 0,
#   'float_count': 6,
#   'integer_count': 3},
#  '/pvc/Geschaeftsberichte/degewo AG/212131_degewo_2022_Konzernlagebericht_Konzernabschluss.pdf_29_GuV': {'word_counts': {'Steuern': 0,
#    'Einkommen': 0,
#    'Umsatzerlöse': 0,
#    'Abgaben': 0,
#    'Bestands': 0,
#    'Jahresüberschuss': 0,
#    'Umsatz': 0,
#    'Finanzanlagevermögens': 0,
#    'Ertrag': 0,
#    'Geschäftsjahr': 0,
#    'Sachanlagen': 1,
#    'Anlagevermögens': 0,
#    'Vermögensgegenstände': 3,
#    'Vorjahr': 1,
#    'Hilfs': 0,
#    'Aufwendungen': 0,
#    'Kapitalgesellschaft': 0,
#    'Zinsen': 0,
#    'Erhöhung': 0,
#    'Verminderung': 0,
#    'Erträge': 0,
#    'Ergebnis': 0,
#    'Bruttoergebnis': 0,
#    'Löhne': 0,
#    'Altersversorgung': 0,
#    'Wertpapiere': 0,
#    'Vertriebskosten': 0,
#    'Betriebsstoffe': 0,
#    'Unterstützung': 0,
#    'Abschreibungen': 0,
#    'Verwaltungskosten': 0,
#    'Roh': 0,
#    'Finanzanlagen': 1,
#    'Gewinn': 0,
#    'Leistungen': 3,
#    'Umlaufvermögens': 0,
#    'Beteiligungen': 2,
#    'Unternehmen': 7,
#    'Erzeugnissen': 0,
#    'Eigenleistungen': 0,
#    'Materialaufwand': 0,
#    'Herstellungskosten': 0,
#    'Personalaufwand': 0,
#    'Erzielung': 0,
#    'Gehälter': 0,
#    'Ausleihungen': 4,
#    'Verlustrechnung': 0,
#    'Jahresfehlbetrag': 0,
#    'Wertpapieren': 0,
#    'GuV': 0},
#   'total_words': 388,
#   'page': 30,
#   'type': 'GuV',
#   'file_path': '/pvc/Geschaeftsberichte/degewo AG/212131_degewo_2022_Konzernlagebericht_Konzernabschluss.pdf',
#   'date_count': 2,
#   'float_count': 138,
#   'integer_count': 26},
#  '/pvc/Geschaeftsberichte/degewo AG/212131_degewo_2022_Konzernlagebericht_Konzernabschluss.pdf_29_Aktiva': {'word_counts': {'Anteile': 1,
#    'Steuern': 0,
#    'Werten': 0,
#    'Erzeugnisse': 0,
#    'Forderungen': 7,
#    'III': 2,
#    'Bundesbankguthaben': 0,
#    'Immaterielle': 2,
#    'Geschäftsjahr': 0,
#    'Aktivseite': 0,
#    'Rechnungsabgrenzungsposten': 2,
#    'Anlagen': 5,
#    'Kassenbestand': 1,
#    'Sachanlagen': 1,
#    'Umlaufvermögen': 1,
#    'Anlagevermögens': 0,
#    'Rechte': 2,
#    'Vermögensgegenstände': 3,
#    'Vorjahr': 1,
#    'Unterschiedsbetrag': 0,
#    'Hilfs': 0,
#    'Aktiva': 1,
#    'Guthaben': 1,
#    'Kreditinstituten': 1,
#    'Konzessionen': 0,
#    'Vorräte': 2,
#    'Bauten': 5,
#    'Wertpapiere': 0,
#    'Betriebsstoffe': 0,
#    'Firmenwert': 1,
#    'Betriebs': 1,
#    'Anlagevermögen': 1,
#    'Roh': 0,
#    'Finanzanlagen': 1,
#    'Schecks': 0,
#    'Lizenzen': 0,
#    'Grundstücken': 1,
#    'Lieferungen': 1,
#    'Werte': 0,
#    'Anzahlungen': 2,
#    'Geschäftsausstattung': 1,
#    'Rechten': 1,
#    'Bau': 9,
#    'Beteiligungsverhältnis': 2,
#    'Beteiligungen': 2,
#    'Maschinen': 1,
#    'Unternehmen': 7,
#    'Leistungen': 3,
#    'Aktiver': 0,
#    'Vermögensverrechnung': 0,
#    'Aktive': 0,
#    'Grundstücke': 8,
#    'Ausleihungen': 4,
#    'Schutzrechte': 0,
#    'Geschäfts': 3},
#   'total_words': 388,
#   'page': 30,
#   'type': 'Aktiva',
#   'file_path': '/pvc/Geschaeftsberichte/degewo AG/212131_degewo_2022_Konzernlagebericht_Konzernabschluss.pdf',
#   'date_count': 2,
#   'float_count': 138,
#   'integer_count': 26},
#  '/pvc/Geschaeftsberichte/degewo AG/212131_degewo_2022_Konzernlagebericht_Konzernabschluss.pdf_29_Passiva': {'word_counts': {'Anteile': 1,
#    'Steuern': 0,
#    'Kapitalrücklage': 0,
#    'Passivseite': 0,
#    'III': 2,
#    'Gewinnrücklagen': 0,
#    'Verlustvortrag': 0,
#    'Eigenkapital': 0,
#    'Sicherheit': 1,
#    'Jahresüberschuß': 0,
#    'Rechnungsabgrenzungsposten': 2,
#    'Geschäftsjahr': 0,
#    'Vorjahr': 1,
#    'Verpflichtungen': 0,
#    'Annahme': 0,
#    'Gezeichnetes': 0,
#    'Kreditinstituten': 1,
#    'Verbindlichkeiten': 0,
#    'Rückstellungen': 0,
#    'Pensionen': 0,
#    'Passiva': 0,
#    'Lieferungen': 1,
#    'Steuerrückstellungen': 0,
#    'Rücklagen': 0,
#    'Leistungen': 3,
#    'Anzahlungen': 2,
#    'Anleihen': 0,
#    'Beteiligungsverhältnis': 2,
#    'Unternehmen': 7,
#    'Kapital': 0,
#    'Rücklage': 0,
#    'Bestellungen': 0,
#    'Jahresfehlbetrag': 0,
#    'Rahmen': 0,
#    'Wechsel': 0,
#    'Gewinnvortrag': 0,
#    'Ausstellung': 0,
#    'Passive': 0},
#   'total_words': 388,
#   'page': 30,
#   'type': 'Passiva',
#   'file_path': '/pvc/Geschaeftsberichte/degewo AG/212131_degewo_2022_Konzernlagebericht_Konzernabschluss.pdf',
#   'date_count': 2,
#   'float_count': 138,
#   'integer_count': 26},
#  '/pvc/Geschaeftsberichte/degewo AG/212131_degewo_2022_Konzernlagebericht_Konzernabschluss.pdf_30_GuV': {'word_counts': {'Steuern': 2,
#    'Einkommen': 0,
#    'Umsatzerlöse': 0,
#    'Abgaben': 0,
#    'Bestands': 0,
#    'Jahresüberschuss': 0,
#    'Umsatz': 0,
#    'Finanzanlagevermögens': 0,
#    'Ertrag': 0,
#    'Geschäftsjahr': 0,
#    'Sachanlagen': 0,
#    'Anlagevermögens': 0,
#    'Vermögensgegenstände': 0,
#    'Vorjahr': 1,
#    'Hilfs': 0,
#    'Aufwendungen': 0,
#    'Kapitalgesellschaft': 0,
#    'Zinsen': 0,
#    'Erhöhung': 0,
#    'Verminderung': 0,
#    'Erträge': 0,
#    'Ergebnis': 0,
#    'Bruttoergebnis': 0,
#    'Löhne': 0,
#    'Altersversorgung': 0,
#    'Wertpapiere': 0,
#    'Vertriebskosten': 0,
#    'Betriebsstoffe': 0,
#    'Unterstützung': 0,
#    'Abschreibungen': 0,
#    'Verwaltungskosten': 0,
#    'Roh': 0,
#    'Finanzanlagen': 0,
#    'Gewinn': 3,
#    'Leistungen': 1,
#    'Umlaufvermögens': 0,
#    'Beteiligungen': 0,
#    'Unternehmen': 2,
#    'Erzeugnissen': 0,
#    'Eigenleistungen': 0,
#    'Materialaufwand': 0,
#    'Herstellungskosten': 0,
#    'Personalaufwand': 0,
#    'Erzielung': 0,
#    'Gehälter': 0,
#    'Ausleihungen': 0,
#    'Verlustrechnung': 0,
#    'Jahresfehlbetrag': 0,
#    'Wertpapieren': 0,
#    'GuV': 0},
#   'total_words': 265,
#   'page': 31,
#   'type': 'GuV',
#   'file_path': '/pvc/Geschaeftsberichte/degewo AG/212131_degewo_2022_Konzernlagebericht_Konzernabschluss.pdf',
#   'date_count': 2,
#   'float_count': 93,
#   'integer_count': 12},
#  '/pvc/Geschaeftsberichte/degewo AG/212131_degewo_2022_Konzernlagebericht_Konzernabschluss.pdf_30_Aktiva': {'word_counts': {'Anteile': 1,
#    'Steuern': 2,
#    'Werten': 0,
#    'Erzeugnisse': 0,
#    'Forderungen': 0,
#    'III': 1,
#    'Bundesbankguthaben': 0,
#    'Immaterielle': 0,
#    'Geschäftsjahr': 0,
#    'Aktivseite': 0,
#    'Rechnungsabgrenzungsposten': 1,
#    'Anlagen': 0,
#    'Kassenbestand': 0,
#    'Sachanlagen': 0,
#    'Umlaufvermögen': 0,
#    'Anlagevermögens': 0,
#    'Rechte': 0,
#    'Vermögensgegenstände': 0,
#    'Vorjahr': 1,
#    'Unterschiedsbetrag': 1,
#    'Hilfs': 0,
#    'Aktiva': 0,
#    'Guthaben': 0,
#    'Kreditinstituten': 1,
#    'Konzessionen': 0,
#    'Vorräte': 0,
#    'Bauten': 0,
#    'Wertpapiere': 0,
#    'Betriebsstoffe': 0,
#    'Firmenwert': 0,
#    'Betriebs': 0,
#    'Anlagevermögen': 1,
#    'Roh': 0,
#    'Finanzanlagen': 0,
#    'Schecks': 0,
#    'Lizenzen': 0,
#    'Grundstücken': 0,
#    'Lieferungen': 1,
#    'Werte': 0,
#    'Anzahlungen': 1,
#    'Geschäftsausstattung': 0,
#    'Rechten': 0,
#    'Bau': 1,
#    'Beteiligungsverhältnis': 1,
#    'Beteiligungen': 0,
#    'Maschinen': 0,
#    'Unternehmen': 2,
#    'Leistungen': 1,
#    'Aktiver': 0,
#    'Vermögensverrechnung': 0,
#    'Aktive': 0,
#    'Grundstücke': 0,
#    'Ausleihungen': 0,
#    'Schutzrechte': 0,
#    'Geschäfts': 0},
#   'total_words': 265,
#   'page': 31,
#   'type': 'Aktiva',
#   'file_path': '/pvc/Geschaeftsberichte/degewo AG/212131_degewo_2022_Konzernlagebericht_Konzernabschluss.pdf',
#   'date_count': 2,
#   'float_count': 93,
#   'integer_count': 12},
#  '/pvc/Geschaeftsberichte/degewo AG/212131_degewo_2022_Konzernlagebericht_Konzernabschluss.pdf_30_Passiva': {'word_counts': {'Anteile': 1,
#    'Steuern': 2,
#    'Kapitalrücklage': 3,
#    'Passivseite': 0,
#    'III': 1,
#    'Gewinnrücklagen': 2,
#    'Verlustvortrag': 0,
#    'Eigenkapital': 1,
#    'Sicherheit': 1,
#    'Jahresüberschuß': 0,
#    'Rechnungsabgrenzungsposten': 1,
#    'Geschäftsjahr': 0,
#    'Vorjahr': 1,
#    'Verpflichtungen': 0,
#    'Annahme': 0,
#    'Gezeichnetes': 1,
#    'Kreditinstituten': 1,
#    'Verbindlichkeiten': 9,
#    'Rückstellungen': 4,
#    'Pensionen': 1,
#    'Passiva': 1,
#    'Lieferungen': 1,
#    'Steuerrückstellungen': 1,
#    'Rücklagen': 3,
#    'Leistungen': 1,
#    'Anzahlungen': 1,
#    'Anleihen': 0,
#    'Beteiligungsverhältnis': 1,
#    'Unternehmen': 2,
#    'Kapital': 6,
#    'Rücklage': 8,
#    'Bestellungen': 0,
#    'Jahresfehlbetrag': 0,
#    'Rahmen': 0,
#    'Wechsel': 0,
#    'Gewinnvortrag': 0,
#    'Ausstellung': 0,
#    'Passive': 1},
#   'total_words': 265,
#   'page': 31,
#   'type': 'Passiva',
#   'file_path': '/pvc/Geschaeftsberichte/degewo AG/212131_degewo_2022_Konzernlagebericht_Konzernabschluss.pdf',
#   'date_count': 2,
#   'float_count': 93,
#   'integer_count': 12},
#  '/pvc/Geschaeftsberichte/degewo AG/212131_degewo_2022_Konzernlagebericht_Konzernabschluss.pdf_31_GuV': {'word_counts': {'Steuern': 0,
#    'Einkommen': 0,
#    'Umsatzerlöse': 0,
#    'Abgaben': 0,
#    'Bestands': 0,
#    'Jahresüberschuss': 0,
#    'Umsatz': 0,
#    'Finanzanlagevermögens': 0,
#    'Ertrag': 0,
#    'Geschäftsjahr': 0,
#    'Sachanlagen': 0,
#    'Anlagevermögens': 0,
#    'Vermögensgegenstände': 0,
#    'Vorjahr': 0,
#    'Hilfs': 0,
#    'Aufwendungen': 0,
#    'Kapitalgesellschaft': 0,
#    'Zinsen': 0,
#    'Erhöhung': 0,
#    'Verminderung': 0,
#    'Erträge': 0,
#    'Ergebnis': 0,
#    'Bruttoergebnis': 0,
#    'Löhne': 0,
#    'Altersversorgung': 0,
#    'Wertpapiere': 0,
#    'Vertriebskosten': 0,
#    'Betriebsstoffe': 0,
#    'Unterstützung': 0,
#    'Abschreibungen': 0,
#    'Verwaltungskosten': 0,
#    'Roh': 0,
#    'Finanzanlagen': 0,
#    'Gewinn': 0,
#    'Leistungen': 0,
#    'Umlaufvermögens': 0,
#    'Beteiligungen': 0,
#    'Unternehmen': 0,
#    'Erzeugnissen': 0,
#    'Eigenleistungen': 0,
#    'Materialaufwand': 0,
#    'Herstellungskosten': 0,
#    'Personalaufwand': 0,
#    'Erzielung': 0,
#    'Gehälter': 0,
#    'Ausleihungen': 0,
#    'Verlustrechnung': 0,
#    'Jahresfehlbetrag': 0,
#    'Wertpapieren': 0,
#    'GuV': 0},
#   'total_words': 0,
#   'page': 32,
#   'type': 'GuV',
#   'file_path': '/pvc/Geschaeftsberichte/degewo AG/212131_degewo_2022_Konzernlagebericht_Konzernabschluss.pdf',
#   'date_count': 0,
#   'float_count': 0,
#   'integer_count': 0},
#  ...}

# %%
import pandas as pd
import numpy as np

df_word_counts = pd.DataFrame(tf_dict).T
df_word_counts['sum_of_word_counts'] = df_word_counts['word_counts'].apply(lambda x: sum(x.values()))
df_word_counts['filename'] = df_word_counts['file_path'].str.split('/').str[-1]
df_word_counts['filepath'] = df_word_counts['file_path'].str.replace("/pvc/", "../")
df_word_counts['term_frequency'] = df_word_counts.apply(
    lambda row: row['sum_of_word_counts'] / row['total_words'] if row['total_words'] > 0 else 0,
    axis=1
)
df_word_counts['float_frequency'] = df_word_counts.apply(
    lambda row: row['float_count'] / row['total_words'] if row['total_words'] > 0 else 0,
    axis=1
)
df_word_counts.drop(columns=['file_path'], inplace=True)
df_word_counts
# Out:
#                                                                                           word_counts  \
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...  {'Steuern': 0, 'Einkommen': 0, 'Umsatzerlöse':...
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...  {'Anteile': 0, 'Steuern': 0, 'Werten': 0, 'Erz...
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...  {'Anteile': 0, 'Steuern': 0, 'Kapitalrücklage'...
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...  {'Steuern': 0, 'Einkommen': 0, 'Umsatzerlöse':...
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...  {'Anteile': 0, 'Steuern': 0, 'Werten': 0, 'Erz...
# ...                                                                                               ...
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...  {'Anteile': 0, 'Steuern': 0, 'Werten': 0, 'Erz...
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...  {'Anteile': 0, 'Steuern': 0, 'Kapitalrücklage'...
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...  {'Steuern': 0, 'Einkommen': 0, 'Umsatzerlöse':...
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...  {'Anteile': 0, 'Steuern': 0, 'Werten': 0, 'Erz...
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...  {'Anteile': 0, 'Steuern': 0, 'Kapitalrücklage'...
#
#                                                    total_words page     type  \
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...          30    1      GuV
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...          30    1   Aktiva
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...          30    1  Passiva
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...           3    2      GuV
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...           3    2   Aktiva
# ...                                                        ...  ...      ...
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...          37   19   Aktiva
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...          37   19  Passiva
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...          15   20      GuV
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...          15   20   Aktiva
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...          15   20  Passiva
#
#                                                    date_count float_count  \
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...          0           5
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...          0           5
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...          0           5
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...          0           2
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...          0           2
# ...                                                       ...         ...
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...          0           6
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...          0           6
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...          0           3
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...          0           3
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...          0           3
#
#                                                    integer_count  \
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...             2
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...             2
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...             2
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...             1
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...             1
# ...                                                          ...
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...             6
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...             6
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...             3
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...             3
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...             3
#
#                                                     sum_of_word_counts  \
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...                   1
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...                   2
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...                   1
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...                   0
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...                   0
# ...                                                                ...
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...                   0
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...                   0
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...                   0
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...                   0
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...                   0
#
#                                                                                 filename  \
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...     Jahresabschluss-BEN-GmbH-2023.pdf
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...     Jahresabschluss-BEN-GmbH-2023.pdf
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...     Jahresabschluss-BEN-GmbH-2023.pdf
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...     Jahresabschluss-BEN-GmbH-2023.pdf
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...     Jahresabschluss-BEN-GmbH-2023.pdf
# ...                                                                                  ...
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...  AP_Geschaeftsbericht_DE_2023_BBB.pdf
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...  AP_Geschaeftsbericht_DE_2023_BBB.pdf
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...  AP_Geschaeftsbericht_DE_2023_BBB.pdf
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...  AP_Geschaeftsbericht_DE_2023_BBB.pdf
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...  AP_Geschaeftsbericht_DE_2023_BBB.pdf
#
#                                                                                              filepath  \
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...  ../Geschaeftsberichte/Berlin Energie und Netzh...
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...  ../Geschaeftsberichte/Berlin Energie und Netzh...
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...  ../Geschaeftsberichte/Berlin Energie und Netzh...
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...  ../Geschaeftsberichte/Berlin Energie und Netzh...
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...  ../Geschaeftsberichte/Berlin Energie und Netzh...
# ...                                                                                               ...
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...  ../Geschaeftsberichte/Amt für Statistik Berlin...
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...  ../Geschaeftsberichte/Amt für Statistik Berlin...
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...  ../Geschaeftsberichte/Amt für Statistik Berlin...
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...  ../Geschaeftsberichte/Amt für Statistik Berlin...
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...  ../Geschaeftsberichte/Amt für Statistik Berlin...
#
#                                                     term_frequency  \
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...        0.033333
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...        0.066667
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...        0.033333
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...        0.000000
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...        0.000000
# ...                                                            ...
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...        0.000000
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...        0.000000
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...        0.000000
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...        0.000000
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...        0.000000
#
#                                                     float_frequency
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...         0.166667
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...         0.166667
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...         0.166667
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...         0.666667
# /pvc/Geschaeftsberichte/Berlin Energie und Netz...         0.666667
# ...                                                             ...
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...         0.162162
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...         0.162162
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...         0.200000
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...         0.200000
# /pvc/Geschaeftsberichte/Amt für Statistik Berli...         0.200000
#
# [15768 rows x 12 columns]

# %%
df_truth = pd.read_csv("/home/simon/Documents/data_science/Thesis/benchmark_truth/aktiva_passiva_guv_table_pages_no_ocr.csv")
df_truth.rename(columns={"page": "page_truth"}, inplace=True)

df_truth['type'] = df_truth['type'].str.split("&")
df_truth = df_truth.explode('type')
df_truth
# Out:
#                                               filepath  page_truth     type
# 0    ../Geschaeftsberichte/Berliner Bäder Betriebe/...          10   Aktiva
# 1    ../Geschaeftsberichte/Berliner Bäder Betriebe/...          11  Passiva
# 2    ../Geschaeftsberichte/Berliner Bäder Betriebe/...          13      GuV
# 3    ../Geschaeftsberichte/Berliner Bäder Betriebe/...          28   Aktiva
# 4    ../Geschaeftsberichte/Berliner Bäder Betriebe/...          29  Passiva
# ..                                                 ...         ...      ...
# 247  ../Geschaeftsberichte/GESOBAU AG/GESOBAU_Gesch...          44      GuV
# 248  ../Geschaeftsberichte/GESOBAU AG/GESOBAU_Gesch...          62      GuV
# 249  ../Geschaeftsberichte/GESOBAU AG/GESOBAU_Gesch...          52   Aktiva
# 250  ../Geschaeftsberichte/GESOBAU AG/GESOBAU_Gesch...          53  Passiva
# 251  ../Geschaeftsberichte/GESOBAU AG/GESOBAU_Gesch...          54      GuV
#
# [265 rows x 3 columns]

# %%
df_check = df_word_counts[
    (df_word_counts['filename'] == 'Jahresabschluss-BEN-GmbH-2023.pdf')
    & (df_word_counts['type'] == 'GuV')
].sort_values(by='term_frequency', ascending=False)

df_check = df_check.merge(df_truth, on=["filepath", "type"], how="left")
df_check
# Out:
#                                            word_counts total_words page type  \
# 0    {'Steuern': 0, 'Einkommen': 0, 'Umsatzerlöse':...         275   30  GuV
# 1    {'Steuern': 0, 'Einkommen': 0, 'Umsatzerlöse':...         275   30  GuV
# 2    {'Steuern': 1, 'Einkommen': 0, 'Umsatzerlöse':...          98   40  GuV
# 3    {'Steuern': 1, 'Einkommen': 0, 'Umsatzerlöse':...          98   40  GuV
# 4    {'Steuern': 2, 'Einkommen': 0, 'Umsatzerlöse':...         152   23  GuV
# ..                                                 ...         ...  ...  ...
# 107  {'Steuern': 0, 'Einkommen': 0, 'Umsatzerlöse':...           0   54  GuV
# 108  {'Steuern': 0, 'Einkommen': 0, 'Umsatzerlöse':...           4   55  GuV
# 109  {'Steuern': 0, 'Einkommen': 0, 'Umsatzerlöse':...           4   55  GuV
# 110  {'Steuern': 0, 'Einkommen': 0, 'Umsatzerlöse':...           5   56  GuV
# 111  {'Steuern': 0, 'Einkommen': 0, 'Umsatzerlöse':...           5   56  GuV
#
#     date_count float_count integer_count  sum_of_word_counts  \
# 0            1          31             4                  42
# 1            1          31             4                  42
# 2            0          37            23                  13
# 3            0          37            23                  13
# 4            3          47             2                  20
# ..         ...         ...           ...                 ...
# 107          0           0             0                   0
# 108          0           0             0                   0
# 109          0           0             0                   0
# 110          0           3             2                   0
# 111          0           3             2                   0
#
#                               filename  \
# 0    Jahresabschluss-BEN-GmbH-2023.pdf
# 1    Jahresabschluss-BEN-GmbH-2023.pdf
# 2    Jahresabschluss-BEN-GmbH-2023.pdf
# 3    Jahresabschluss-BEN-GmbH-2023.pdf
# 4    Jahresabschluss-BEN-GmbH-2023.pdf
# ..                                 ...
# 107  Jahresabschluss-BEN-GmbH-2023.pdf
# 108  Jahresabschluss-BEN-GmbH-2023.pdf
# 109  Jahresabschluss-BEN-GmbH-2023.pdf
# 110  Jahresabschluss-BEN-GmbH-2023.pdf
# 111  Jahresabschluss-BEN-GmbH-2023.pdf
#
#                                               filepath  term_frequency  \
# 0    ../Geschaeftsberichte/Berlin Energie und Netzh...        0.152727
# 1    ../Geschaeftsberichte/Berlin Energie und Netzh...        0.152727
# 2    ../Geschaeftsberichte/Berlin Energie und Netzh...        0.132653
# 3    ../Geschaeftsberichte/Berlin Energie und Netzh...        0.132653
# 4    ../Geschaeftsberichte/Berlin Energie und Netzh...        0.131579
# ..                                                 ...             ...
# 107  ../Geschaeftsberichte/Berlin Energie und Netzh...        0.000000
# 108  ../Geschaeftsberichte/Berlin Energie und Netzh...        0.000000
# 109  ../Geschaeftsberichte/Berlin Energie und Netzh...        0.000000
# 110  ../Geschaeftsberichte/Berlin Energie und Netzh...        0.000000
# 111  ../Geschaeftsberichte/Berlin Energie und Netzh...        0.000000
#
#      float_frequency  page_truth
# 0           0.112727          23
# 1           0.112727          43
# 2           0.377551          23
# 3           0.377551          43
# 4           0.309211          23
# ..               ...         ...
# 107         0.000000          43
# 108         0.000000          23
# 109         0.000000          43
# 110         0.600000          23
# 111         0.600000          43
#
# [112 rows x 13 columns]

# %%
df_check = df_word_counts[
    (df_word_counts['filename'] == 'Jahresabschluss-BEN-GmbH-2023.pdf')
    & (df_word_counts['type'] == 'Aktiva')
].sort_values(by='term_frequency', ascending=False)

df_check = df_check.merge(df_truth, on=["filepath", "type"], how="left")
df_check
# Out:
#                                            word_counts total_words page  \
# 0    {'Anteile': 0, 'Steuern': 0, 'Werten': 0, 'Erz...           5   35
# 1    {'Anteile': 0, 'Steuern': 0, 'Werten': 0, 'Erz...           5   35
# 2    {'Anteile': 1, 'Steuern': 0, 'Werten': 1, 'Erz...         163   37
# 3    {'Anteile': 1, 'Steuern': 0, 'Werten': 1, 'Erz...         163   37
# 4    {'Anteile': 0, 'Steuern': 0, 'Werten': 0, 'Erz...         120   42
# ..                                                 ...         ...  ...
# 107  {'Anteile': 0, 'Steuern': 0, 'Werten': 0, 'Erz...           0   54
# 108  {'Anteile': 0, 'Steuern': 0, 'Werten': 0, 'Erz...           4   55
# 109  {'Anteile': 0, 'Steuern': 0, 'Werten': 0, 'Erz...           4   55
# 110  {'Anteile': 0, 'Steuern': 0, 'Werten': 0, 'Erz...           5   56
# 111  {'Anteile': 0, 'Steuern': 0, 'Werten': 0, 'Erz...           5   56
#
#        type date_count float_count integer_count  sum_of_word_counts  \
# 0    Aktiva          0           3             2                   1
# 1    Aktiva          0           3             2                   1
# 2    Aktiva          5          44             1                  25
# 3    Aktiva          5          44             1                  25
# 4    Aktiva          4          33             2                  17
# ..      ...        ...         ...           ...                 ...
# 107  Aktiva          0           0             0                   0
# 108  Aktiva          0           0             0                   0
# 109  Aktiva          0           0             0                   0
# 110  Aktiva          0           3             2                   0
# 111  Aktiva          0           3             2                   0
#
#                               filename  \
# 0    Jahresabschluss-BEN-GmbH-2023.pdf
# 1    Jahresabschluss-BEN-GmbH-2023.pdf
# 2    Jahresabschluss-BEN-GmbH-2023.pdf
# 3    Jahresabschluss-BEN-GmbH-2023.pdf
# 4    Jahresabschluss-BEN-GmbH-2023.pdf
# ..                                 ...
# 107  Jahresabschluss-BEN-GmbH-2023.pdf
# 108  Jahresabschluss-BEN-GmbH-2023.pdf
# 109  Jahresabschluss-BEN-GmbH-2023.pdf
# 110  Jahresabschluss-BEN-GmbH-2023.pdf
# 111  Jahresabschluss-BEN-GmbH-2023.pdf
#
#                                               filepath  term_frequency  \
# 0    ../Geschaeftsberichte/Berlin Energie und Netzh...        0.200000
# 1    ../Geschaeftsberichte/Berlin Energie und Netzh...        0.200000
# 2    ../Geschaeftsberichte/Berlin Energie und Netzh...        0.153374
# 3    ../Geschaeftsberichte/Berlin Energie und Netzh...        0.153374
# 4    ../Geschaeftsberichte/Berlin Energie und Netzh...        0.141667
# ..                                                 ...             ...
# 107  ../Geschaeftsberichte/Berlin Energie und Netzh...        0.000000
# 108  ../Geschaeftsberichte/Berlin Energie und Netzh...        0.000000
# 109  ../Geschaeftsberichte/Berlin Energie und Netzh...        0.000000
# 110  ../Geschaeftsberichte/Berlin Energie und Netzh...        0.000000
# 111  ../Geschaeftsberichte/Berlin Energie und Netzh...        0.000000
#
#      float_frequency  page_truth
# 0           0.600000          21
# 1           0.600000          42
# 2           0.269939          21
# 3           0.269939          42
# 4           0.275000          21
# ..               ...         ...
# 107         0.000000          42
# 108         0.000000          21
# 109         0.000000          42
# 110         0.600000          21
# 111         0.600000          42
#
# [112 rows x 13 columns]

# %%
# Prepare training data
# For each file and type, label the correct page as 1, others as 0
df_train = df_word_counts.merge(df_truth, on=["filepath", "type"], how="left")
df_train["is_truth"] = (df_train["page"] == df_train["page_truth"]).astype(int)

# Balance the dataset: sample equal number of True/False labels
n_true = df_train["is_truth"].sum()
df_true = df_train[df_train["is_truth"] == 1]
df_false_all = df_train[df_train["is_truth"] == 0]
df_false = df_false_all.sample(n=n_true, random_state=42)
df_train = pd.concat([df_true, df_false]).sample(frac=1, random_state=42).reset_index(drop=True)

df_train
# Out:
#                                            word_counts total_words page  \
# 0    {'Anteile': 0, 'Steuern': 0, 'Kapitalrücklage'...         147   29
# 1    {'Steuern': 0, 'Einkommen': 0, 'Umsatzerlöse':...         202   98
# 2    {'Anteile': 0, 'Steuern': 0, 'Werten': 0, 'Erz...         121   20
# 3    {'Steuern': 0, 'Einkommen': 0, 'Umsatzerlöse':...         554   23
# 4    {'Anteile': 0, 'Steuern': 0, 'Werten': 0, 'Erz...         122  102
# ..                                                 ...         ...  ...
# 525  {'Anteile': 0, 'Steuern': 1, 'Kapitalrücklage'...         289   21
# 526  {'Anteile': 0, 'Steuern': 0, 'Werten': 0, 'Erz...         168   28
# 527  {'Steuern': 0, 'Einkommen': 0, 'Umsatzerlöse':...         167    2
# 528  {'Anteile': 0, 'Steuern': 0, 'Werten': 0, 'Erz...           1   53
# 529  {'Steuern': 4, 'Einkommen': 1, 'Umsatzerlöse':...         447   44
#
#         type date_count float_count integer_count  sum_of_word_counts  \
# 0    Passiva          2          38             1                  19
# 1        GuV          0           4             3                   1
# 2     Aktiva          3          30             1                  21
# 3        GuV          1          61            43                   7
# 4     Aktiva          0          36            26                   2
# ..       ...        ...         ...           ...                 ...
# 525  Passiva          2          69             5                  40
# 526   Aktiva          0          35             2                  43
# 527      GuV          1           8             5                   2
# 528   Aktiva          0           1             1                   0
# 529      GuV          2          92             4                  62
#
#                                               filename  \
# 0                            GB_BBB_Infra_2022_low.pdf
# 1                       ibb_geschaeftsbericht_2007.pdf
# 2    SIGNATURE_DEE00084236.1.1_550912_Endexemplar_2...
# 3                   Finanzbericht_Berlinovo_2022_s.pdf
# 4                       ibb_geschaeftsbericht_2014.pdf
# ..                                                 ...
# 525          020712_BIH_Jaresabschluss_2010_online.pdf
# 526                              GB_BBB_Infra_2020.pdf
# 527                     ibb_geschaeftsbericht_2019.pdf
# 528                     2021_Geschaeftsbericht_BBB.pdf
# 529              Finanzbericht_Berlinovo_2022_bf_s.pdf
#
#                                               filepath  term_frequency  \
# 0    ../Geschaeftsberichte/Berliner Bäder Betriebe/...        0.129252
# 1    ../Geschaeftsberichte/IBB/ibb_geschaeftsberich...        0.004950
# 2    ../Geschaeftsberichte/Berlin Energie und Netzh...        0.173554
# 3    ../Geschaeftsberichte/Berlinovo/Finanzbericht_...        0.012635
# 4    ../Geschaeftsberichte/IBB/ibb_geschaeftsberich...        0.016393
# ..                                                 ...             ...
# 525  ../Geschaeftsberichte/Berlinovo/020712_BIH_Jar...        0.138408
# 526  ../Geschaeftsberichte/Berliner Bäder Betriebe/...        0.255952
# 527  ../Geschaeftsberichte/IBB/ibb_geschaeftsberich...        0.011976
# 528  ../Geschaeftsberichte/Berliner Bäder Betriebe/...        0.000000
# 529  ../Geschaeftsberichte/Berlinovo/Finanzbericht_...        0.138702
#
#      float_frequency  page_truth  is_truth
# 0           0.258503        29.0         1
# 1           0.019802        76.0         0
# 2           0.247934        20.0         1
# 3           0.110108        44.0         0
# 4           0.295082        74.0         0
# ..               ...         ...       ...
# 525         0.238754        21.0         1
# 526         0.208333        28.0         1
# 527         0.047904        46.0         0
# 528         1.000000        34.0         0
# 529         0.205817        44.0         1
#
# [530 rows x 14 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import numpy as np

# Drop rows without ground truth
df_train = df_train.dropna(subset=["page_truth"])

# Features and target
X = df_train[["term_frequency", "float_frequency"]].values
y = df_train["is_truth"].values

# Train-test split (70% train, 30% test)
X_train, X_test, y_train, y_test, df_train_split, df_test_split = train_test_split(
    X, y, df_train, test_size=0.3, random_state=42, stratify=y
)

# Train logistic regression model
clf = LogisticRegression()
clf.fit(X_train, y_train)

# Predict and rerank: get predicted probabilities for each page
df_train_split["score"] = clf.predict_proba(X_train)[:, 1]
df_test_split["score"] = clf.predict_proba(X_test)[:, 1]

# Add all not-chosen negatives from df_false_all to test split
df_false_unused = df_false_all.loc[~df_false_all.index.isin(df_false.index)]
df_false_unused = df_false_unused.copy()
df_false_unused["score"] = clf.predict_proba(df_false_unused[["term_frequency", "float_frequency"]].values)[:, 1]
df_false_unused["rank"] = np.nan  # Not ranked yet

# Concatenate with test split
df_test_split = pd.concat([df_test_split, df_false_unused], ignore_index=True)

# For each group (filepath, type), sort by score descending
df_train_split["rank"] = df_train_split.groupby(["filepath", "type"])["score"].rank(ascending=False, method="first")
df_test_split["rank"] = df_test_split.groupby(["filepath", "type"])["score"].rank(ascending=False, method="first")

# Check accuracy: how often is the correct page ranked 1?
top1_train = df_train_split[df_train_split["is_truth"] == 1]["rank"].eq(1).mean()
top5_train = df_train_split[df_train_split["is_truth"] == 1]["rank"].le(5).mean()
top1_test = df_test_split[df_test_split["is_truth"] == 1]["rank"].eq(1).mean()
top5_test = df_test_split[df_test_split["is_truth"] == 1]["rank"].le(5).mean()

print(f"Train Top-1 accuracy: {top1_train:.2%}")
print(f"Train Top-5 accuracy: {top5_train:.2%}")
print(f"Test Top-1 accuracy: {top1_test:.2%}")
print(f"Test Top-5 accuracy: {top5_test:.2%}")

# Show top-ranked pages for a sample file/type in test set
sample = df_test_split[(df_test_split["filename"] == 'Jahresabschluss-BEN-GmbH-2023.pdf') & (df_test_split["type"] == "GuV")]
print(sample.sort_values("score", ascending=False)[["page", "score", "is_truth"]])
# Out:
# Train Top-1 accuracy: 85.95%
# Train Top-5 accuracy: 100.00%
# Test Top-1 accuracy: 28.75%
# Test Top-5 accuracy: 76.25%
#     page     score  is_truth
# 163    2  0.721296         0
# 162    2  0.721296         0
# 386   40  0.718654         0
# 385   40  0.718654         0
# 356   35  0.675456         0
# ..   ...       ...       ...
# 418   46  0.226456         0
# 464   54  0.226456         0
# 463   54  0.226456         0
# 470   55  0.226456         0
# 469   55  0.226456         0
#
# [110 rows x 3 columns]

# %%
import numpy as np

import matplotlib.pyplot as plt

# Calculate top-n accuracy for n from 1 to max rank
max_rank = int(df_test_split["rank"].max())
topn_accuracies = [
    df_test_split[df_test_split["is_truth"] == 1]["rank"].le(n).mean()
    for n in range(1, max_rank + 1)
]

plt.figure(figsize=(8, 5))
plt.bar(range(1, max_rank + 1), np.array(topn_accuracies) * 100)
plt.xlabel("Rank (n)")
plt.ylabel("Cumulative Top-n Accuracy (%)")
plt.title("Cumulative Top-n Accuracy by Rank")
plt.xticks(range(1, max_rank + 1))
plt.ylim(0, 100)
plt.xlim(0, 11 + 0.5)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.scatter(df_test_split["score"], df_test_split["is_truth"], alpha=0.5)
plt.xlabel("Score")
plt.ylabel("Is Truth")
plt.title("Score vs. Is Truth")
plt.yticks([0, 1])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.scatter(df_test_split["score"], df_test_split["rank"], c=df_test_split["is_truth"], cmap="coolwarm", alpha=0.5)
plt.xlabel("Score")
plt.ylabel("Rank")
plt.title("Score vs. Rank")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.scatter(df_train_split["score"], df_train_split["rank"], c=df_train_split["is_truth"], cmap="coolwarm", alpha=0.5)
plt.xlabel("Score")
plt.ylabel("Rank")
plt.title("Score vs. Rank")
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
import numpy as np

# Drop rows without ground truth
df_train_os = df_word_counts.merge(df_truth, on=["filepath", "type"], how="left")
df_train_os["is_truth"] = (df_train_os["page"] == df_train_os["page_truth"]).astype(int)
df_train_os = df_train_os.dropna(subset=["page_truth"])

# Oversample the minority class (is_truth == 1)
df_true = df_train_os[df_train_os["is_truth"] == 1]
df_false = df_train_os[df_train_os["is_truth"] == 0]
df_true_oversampled = resample(
    df_true,
    replace=True,
    n_samples=len(df_false),
    random_state=42
)
df_train_os_balanced = pd.concat([df_false, df_true_oversampled]).sample(frac=1, random_state=42).reset_index(drop=True)

# Features and target
X = df_train_os_balanced[["term_frequency", "float_frequency"]].values
y = df_train_os_balanced["is_truth"].values

# Train-test split (70% train, 30% test)
X_train, X_test, y_train, y_test, df_train_split, df_test_split = train_test_split(
    X, y, df_train_os_balanced, test_size=0.3, random_state=42, stratify=y
)

# Train logistic regression model
clf = LogisticRegression()
clf.fit(X_train, y_train)

# Predict and rerank: get predicted probabilities for each page
df_train_split["score"] = clf.predict_proba(X_train)[:, 1]
df_test_split["score"] = clf.predict_proba(X_test)[:, 1]

# For each group (filepath, type), sort by score descending
df_train_split["rank"] = df_train_split.groupby(["filepath", "type"])["score"].rank(ascending=False, method="first")
df_test_split["rank"] = df_test_split.groupby(["filepath", "type"])["score"].rank(ascending=False, method="first")

# Check accuracy: how often is the correct page ranked 1?
top1_train = df_train_split[df_train_split["is_truth"] == 1]["rank"].eq(1).mean()
top5_train = df_train_split[df_train_split["is_truth"] == 1]["rank"].le(5).mean()
top1_test = df_test_split[df_test_split["is_truth"] == 1]["rank"].eq(1).mean()
top5_test = df_test_split[df_test_split["is_truth"] == 1]["rank"].le(5).mean()

print(f"Train Top-1 accuracy: {top1_train:.2%}")
print(f"Train Top-5 accuracy: {top5_train:.2%}")
print(f"Test Top-1 accuracy: {top1_test:.2%}")
print(f"Test Top-5 accuracy: {top5_test:.2%}")

# Show top-ranked pages for a sample file/type in test set
sample = df_test_split[(df_test_split["filename"] == 'Jahresabschluss-BEN-GmbH-2023.pdf') & (df_test_split["type"] == "GuV")]
print(sample.sort_values("score", ascending=False)[["page", "score", "is_truth"]])
# Out:
# Train Top-1 accuracy: 1.28%
# Train Top-5 accuracy: 8.00%
# Test Top-1 accuracy: 3.50%
# Test Top-5 accuracy: 19.92%
#       page     score  is_truth
# 27257   30  0.945797         0
# 7285    23  0.911847         1
# 31342   23  0.911847         1
# 19051   23  0.911847         1
# 5471    23  0.911847         1
# ...    ...       ...       ...
# 9341    49  0.021665         0
# 33196   49  0.021665         0
# 33704   36  0.018854         0
# 12475   18  0.018854         0
# 10370   46  0.018854         0
#
# [66 rows x 3 columns]

# %%
df_word_counts.merge(df_truth, on=["filepath", "type"], how="left").to_csv("/home/simon/Documents/data_science/Thesis/benchmark_results/page_identification/term_frequency_table.csv", index=False)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# Drop rows without ground truth
df_train_us = df_word_counts.merge(df_truth, on=["filepath", "type"], how="left")
df_train_us["is_truth"] = (df_train_us["page"] == df_train_us["page_truth"]).astype(int)
df_train_us = df_train_us.dropna(subset=["page_truth"])
# df_train_us = df_train_us[df_train_us['type'].isin(['Aktiva'])]  # Filter for relevant types

# Undersample the majority class (is_truth == 0)
df_true = df_train_us[df_train_us["is_truth"] == 1]
df_false = df_train_us[df_train_us["is_truth"] == 0]
df_false_undersampled = df_false.sample(n=len(df_true), random_state=42)
df_train_us_balanced = pd.concat([df_true, df_false_undersampled]).sample(frac=1, random_state=42).reset_index(drop=True)
df_train_us_balanced

# Features and target
X = df_train_us_balanced[["term_frequency", "float_frequency"]].values
y = df_train_us_balanced["is_truth"].values

# Train-test split (70% train, 30% test)
X_train, X_test, y_train, y_test, df_train_split, df_test_split = train_test_split(
    X, y, df_train_us_balanced, test_size=0.3, random_state=42, stratify=y
)

# Train Random Forest model
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)
score = clf.score(X_train, y_train)
print(f"Training accuracy: {score:.2%}")
score = clf.score(X_test, y_test)
print(f"Test accuracy: {score:.2%}")

# Predict and rerank: get predicted probabilities for each page
df_train_split["score"] = clf.predict_proba(X_train)[:, 1]
df_test_split["score"] = clf.predict_proba(X_test)[:, 1]

# Add all not-chosen negatives from df_false to test split
df_false_unused = df_false.loc[~df_false.index.isin(df_false_undersampled.index)]
df_false_unused = df_false_unused.copy()
df_false_unused["score"] = clf.predict_proba(df_false_unused[["term_frequency", "float_frequency"]].values)[:, 1]
df_false_unused["rank"] = np.nan  # Not ranked yet

# Concatenate with test split
df_test_split = pd.concat([df_test_split, df_false_unused], ignore_index=True)

# For each group (filepath, type), sort by score descending
df_train_split["rank"] = df_train_split.groupby(["filepath", "type"])["score"].rank(ascending=False, method="first")
df_test_split["rank"] = df_test_split.groupby(["filepath", "type"])["score"].rank(ascending=False, method="first")

# Check accuracy: how often is the correct page ranked among the top k?
top1_train = df_train_split[(df_train_split["is_truth"] == 1)]["rank"].eq(1).mean()
top5_train = df_train_split[(df_train_split["is_truth"] == 1)]["rank"].le(5).mean()
top1_test = df_test_split[(df_test_split["is_truth"] == 1)]["rank"].eq(1).mean()
top5_test = df_test_split[(df_test_split["is_truth"] == 1)]["rank"].le(5).mean()

print(f"\nResults for any type:")
print(f"Train Top-1 accuracy: {top1_train:.2%}")
print(f"Train Top-5 accuracy: {top5_train:.2%}")
print(f"Test Top-1 accuracy: {top1_test:.2%}")
print(f"Test Top-5 accuracy: {top5_test:.2%}")

for target in ['Aktiva', 'Passiva', 'GuV']:
    # Check accuracy: how often is the correct page ranked among the top k?
    top1_train = df_train_split[(df_train_split["is_truth"] == 1) & (df_train_split['type'] == target)]["rank"].eq(1).mean()
    top5_train = df_train_split[(df_train_split["is_truth"] == 1) & (df_train_split['type'] == target)]["rank"].le(5).mean()
    top1_test = df_test_split[(df_test_split["is_truth"] == 1) & (df_test_split['type'] == target)]["rank"].eq(1).mean()
    top5_test = df_test_split[(df_test_split["is_truth"] == 1) & (df_test_split['type'] == target)]["rank"].le(5).mean()

    print(f"\nResults for {target}:")
    print(f"Train Top-1 accuracy: {top1_train:.2%}")
    print(f"Train Top-5 accuracy: {top5_train:.2%}")
    print(f"Test Top-1 accuracy: {top1_test:.2%}")
    print(f"Test Top-5 accuracy: {top5_test:.2%}")

# Show top-ranked pages for a sample file/type in test set
sample = df_test_split[(df_test_split["filename"] == 'Jahresabschluss-BEN-GmbH-2023.pdf') & (df_test_split["type"] == "GuV")]
print(sample.sort_values("score", ascending=False)[["page", "score", "is_truth"]])
# Out:
# Training accuracy: 99.73%
# Test accuracy: 98.74%
#
# Results for any type:
# Train Top-1 accuracy: 88.17%
# Train Top-5 accuracy: 100.00%
# Test Top-1 accuracy: 75.95%
# Test Top-5 accuracy: 98.73%
#
# Results for Aktiva:
# Train Top-1 accuracy: 91.53%
# Train Top-5 accuracy: 100.00%
# Test Top-1 accuracy: 69.57%
# Test Top-5 accuracy: 95.65%
#
# Results for Passiva:
# Train Top-1 accuracy: 92.73%
# Train Top-5 accuracy: 100.00%
# Test Top-1 accuracy: 84.62%
# Test Top-5 accuracy: 100.00%
#
# Results for GuV:
# Train Top-1 accuracy: 81.94%
# Train Top-5 accuracy: 100.00%
# Test Top-1 accuracy: 73.33%
# Test Top-5 accuracy: 100.00%
#     page  score  is_truth
# 9     23    1.0         1
# 284   23    1.0         0
# 302   26    1.0         0
# 330   31    1.0         0
# 331   31    1.0         0
# ..   ...    ...       ...
# 457   53    0.0         0
# 463   54    0.0         0
# 458   53    0.0         0
# 469   55    0.0         0
# 468   55    0.0         0
#
# [111 rows x 3 columns]

# %%
df_test_split.to_csv("/home/simon/Documents/data_science/Thesis/benchmark_results/page_identification/term_frequency_results_2_predictors_test.csv", index=False)
df_train_split.to_csv("/home/simon/Documents/data_science/Thesis/benchmark_results/page_identification/term_frequency_results_2_predictors_train.csv", index=False)

# %%
import numpy as np

import matplotlib.pyplot as plt

# Calculate top-n accuracy for n from 1 to max rank
max_rank = int(df_test_split["rank"].max())
topn_accuracies = [
    df_test_split[df_test_split["is_truth"] == 1]["rank"].le(n).mean()
    for n in range(1, max_rank + 1)
]

plt.figure(figsize=(8, 5))
plt.bar(range(1, max_rank + 1), np.array(topn_accuracies) * 100)
plt.xlabel("Rank (n)")
plt.ylabel("Cumulative Top-n Accuracy (%)")
plt.title("Cumulative Top-n Accuracy by Rank")
plt.xticks(range(1, max_rank + 1))
plt.ylim(0, 100)
plt.xlim(0, 11 + 0.5)
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.inspection import DecisionBoundaryDisplay
from matplotlib.colors import ListedColormap
from sklearn.model_selection import train_test_split

# # Prepare data (using df_train_us_balanced from your notebook)
# X = df_train_us_balanced[["term_frequency", "float_frequency"]].values
# y = df_train_us_balanced["is_truth"].values

# # Train-test split
# X_train, X_test, y_train, y_test = train_test_split(
#     X, y, test_size=0.4, random_state=42
# )

# # Fit classifier
# clf = make_pipeline(StandardScaler(), RandomForestClassifier(n_estimators=100, random_state=42))
# clf.fit(X_train, y_train)

# Plot decision boundary
cm = plt.cm.RdBu
cm_bright = ListedColormap(["#FF0000", "#0000FF"])
x_min, x_max = X[:, 0].min() - 0.05, X[:, 0].max() + 0.05
y_min, y_max = X[:, 1].min() - 0.05, X[:, 1].max() + 0.05

plt.figure(figsize=(8, 6))
ax = plt.gca()
DecisionBoundaryDisplay.from_estimator(
    clf, X, cmap=cm, alpha=0.8, ax=ax, eps=0.05
)

df_test_split_sorted = df_test_split.sort_values('is_truth')
X_test = df_test_split_sorted[["term_frequency", "float_frequency"]].values
y_test = df_test_split_sorted["is_truth"].values
score = clf.score(X_test, y_test)

# ax.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap=cm_bright, edgecolors="k", label="Train")
ax.scatter(X_test[:, 0], X_test[:, 1], c=y_test, cmap=cm_bright, alpha=0.6, edgecolors="k", label="Test")
ax.set_xlim(x_min, x_max)
ax.set_ylim(y_min, y_max)
ax.set_xlabel("term_frequency")
ax.set_ylabel("float_frequency")
ax.set_title(f"RandomForestClassifier (accuracy={score:.2f})")
plt.legend()
plt.show()

# %%
topn_accuracies = [
    df_test_split[df_test_split["is_truth"] == 1]["rank"].le(n).mean()
    for n in range(1, 11)
]
df_topn = pd.DataFrame({
    "top_n": range(1, 11),
    "accuracy": topn_accuracies
})
df_topn
# Out:
#    top_n  accuracy
# 0      1  0.759494
# 1      2  0.898734
# 2      3  0.949367
# 3      4  0.962025
# 4      5  0.987342
# 5      6  0.987342
# 6      7  1.000000
# 7      8  1.000000
# 8      9  1.000000
# 9     10  1.000000

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# Drop rows without ground truth
df_train_us = df_word_counts.merge(df_truth, on=["filepath", "type"], how="left")
df_train_us["is_truth"] = (df_train_us["page"] == df_train_us["page_truth"]).astype(int)
df_train_us = df_train_us.dropna(subset=["page_truth"])

# Undersample the majority class (is_truth == 0)
df_true = df_train_us[df_train_us["is_truth"] == 1]
df_false = df_train_us[df_train_us["is_truth"] == 0]
df_false_undersampled = df_false.sample(n=len(df_true), random_state=42)
df_train_us_balanced = pd.concat([df_true, df_false_undersampled]).sample(frac=1, random_state=42).reset_index(drop=True)
df_train_us_balanced

predictors = [
    "term_frequency", 
    "float_frequency", 
    "date_count", 
    "integer_count"
]

# Features and target
X = df_train_us_balanced[predictors].values # only better with date and integer counts; otherwise worse
y = df_train_us_balanced["is_truth"].values

# Train-test split (70% train, 30% test)
X_train, X_test, y_train, y_test, df_train_split, df_test_split = train_test_split(
    X, y, df_train_us_balanced, test_size=0.3, random_state=42, stratify=y
)

# Train Random Forest model
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)

# Predict and rerank: get predicted probabilities for each page
df_train_split["score"] = clf.predict_proba(X_train)[:, 1]
df_test_split["score"] = clf.predict_proba(X_test)[:, 1]

# Add all not-chosen negatives from df_false to test split
df_false_unused = df_false.loc[~df_false.index.isin(df_false_undersampled.index)]
df_false_unused = df_false_unused.copy()
df_false_unused["score"] = clf.predict_proba(df_false_unused[predictors].values)[:, 1]
df_false_unused["rank"] = np.nan  # Not ranked yet

# Concatenate with test split
df_test_split = pd.concat([df_test_split, df_false_unused], ignore_index=True)

# For each group (filepath, type), sort by score descending
df_train_split["rank"] = df_train_split.groupby(["filepath", "type"])["score"].rank(ascending=False, method="first")
df_test_split["rank"] = df_test_split.groupby(["filepath", "type"])["score"].rank(ascending=False, method="first")

# Check accuracy: how often is the correct page ranked among the top k?
top1_train = df_train_split[df_train_split["is_truth"] == 1]["rank"].eq(1).mean()
top5_train = df_train_split[df_train_split["is_truth"] == 1]["rank"].le(5).mean()
top1_test = df_test_split[df_test_split["is_truth"] == 1]["rank"].eq(1).mean()
top5_test = df_test_split[df_test_split["is_truth"] == 1]["rank"].le(5).mean()

print(f"\nResults for any type:")
print(f"Train Top-1 accuracy: {top1_train:.2%}")
print(f"Train Top-5 accuracy: {top5_train:.2%}")
print(f"Test Top-1 accuracy: {top1_test:.2%}")
print(f"Test Top-5 accuracy: {top5_test:.2%}")

for target in ['Aktiva', 'Passiva', 'GuV']:
    # Check accuracy: how often is the correct page ranked among the top k?
    top1_train = df_train_split[(df_train_split["is_truth"] == 1) & (df_train_split['type'] == target)]["rank"].eq(1).mean()
    top5_train = df_train_split[(df_train_split["is_truth"] == 1) & (df_train_split['type'] == target)]["rank"].le(5).mean()
    top1_test = df_test_split[(df_test_split["is_truth"] == 1) & (df_test_split['type'] == target)]["rank"].eq(1).mean()
    top5_test = df_test_split[(df_test_split["is_truth"] == 1) & (df_test_split['type'] == target)]["rank"].le(5).mean()

    print(f"\nResults for {target}:")
    print(f"Train Top-1 accuracy: {top1_train:.2%}")
    print(f"Train Top-5 accuracy: {top5_train:.2%}")
    print(f"Test Top-1 accuracy: {top1_test:.2%}")
    print(f"Test Top-5 accuracy: {top5_test:.2%}")

# Show top-ranked pages for a sample file/type in test set
sample = df_test_split[(df_test_split["filename"] == 'Jahresabschluss-BEN-GmbH-2023.pdf') & (df_test_split["type"] == "GuV")]
print(sample.sort_values("score", ascending=False)[["page", "score", "is_truth"]])
# Out:
# Results for any type:
# Train Top-1 accuracy: 88.17%
# Train Top-5 accuracy: 100.00%
# Test Top-1 accuracy: 77.22%
# Test Top-5 accuracy: 100.00%
#
# Results for Aktiva:
# Train Top-1 accuracy: 91.53%
# Train Top-5 accuracy: 100.00%
# Test Top-1 accuracy: 82.61%
# Test Top-5 accuracy: 100.00%
#
# Results for Passiva:
# Train Top-1 accuracy: 92.73%
# Train Top-5 accuracy: 100.00%
# Test Top-1 accuracy: 80.77%
# Test Top-5 accuracy: 100.00%
#
# Results for GuV:
# Train Top-1 accuracy: 81.94%
# Train Top-5 accuracy: 100.00%
# Test Top-1 accuracy: 70.00%
# Test Top-5 accuracy: 100.00%
#     page  score  is_truth
# 9     23   1.00         1
# 284   23   1.00         0
# 331   31   1.00         0
# 330   31   1.00         0
# 384   40   0.99         0
# ..   ...    ...       ...
# 463   54   0.00         0
# 468   55   0.00         0
# 469   55   0.00         0
# 473   56   0.00         0
# 474   56   0.00         0
#
# [111 rows x 3 columns]

# %%
df_test_split.to_csv("/home/simon/Documents/data_science/Thesis/benchmark_results/page_identification/term_frequency_results_4_predictors_test.csv", index=False)
df_train_split.to_csv("/home/simon/Documents/data_science/Thesis/benchmark_results/page_identification/term_frequency_results_4_predictors_train.csv", index=False)

# %%
# !pip install shap
import shap

# Use the same predictors and trained RandomForestClassifier (clf) as in cell 20
explainer = shap.TreeExplainer(clf)
shap_values = explainer.shap_values(df_test_split[predictors].values)

# Plot summary for class 1 (is_truth == 1)
shap.summary_plot(shap_values[:,:,1], df_test_split[predictors].values, feature_names=predictors)

# %%
topn_accuracies_4_predictors = [
    df_test_split[df_test_split["is_truth"] == 1]["rank"].le(n).mean()
    for n in range(1, 11)
]
df_topn_4_predictors = pd.DataFrame({
    "top_n": range(1, 11),
    "accuracy": topn_accuracies_4_predictors
})

# %%
df_topn_4_predictors.merge(df_topn, on="top_n", suffixes=('_4_predictors', '_2_predictors'))
# Out:
#    top_n  accuracy_4_predictors  accuracy_2_predictors
# 0      1               0.772152               0.759494
# 1      2               0.911392               0.898734
# 2      3               0.962025               0.949367
# 3      4               0.962025               0.962025
# 4      5               1.000000               0.987342
# 5      6               1.000000               0.987342
# 6      7               1.000000               1.000000
# 7      8               1.000000               1.000000
# 8      9               1.000000               1.000000
# 9     10               1.000000               1.000000

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score

import matplotlib.pyplot as plt

# Get predicted probabilities for test set (class 1)
y_score = clf.predict_proba(df_test_split[predictors].values)[:, 1]

# Compute ROC curve and AUC
fpr, tpr, thresholds = roc_curve(df_test_split['is_truth'].values, y_score)
roc_auc = roc_auc_score(df_test_split['is_truth'].values, y_score)

plt.figure(figsize=(8, 5))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.3})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))

for t in df_test_split['type'].unique():
    mask = df_test_split['type'] == t
    y_true = df_test_split.loc[mask, 'is_truth'].values
    y_score = clf.predict_proba(df_test_split.loc[mask, predictors].values)[:, 1]
    fpr, tpr, _ = roc_curve(y_true, y_score)
    roc_auc = roc_auc_score(y_true, y_score)
    plt.plot(fpr, tpr, lw=2, label=f'{t} (AUC = {roc_auc:.3f})')

plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve per Type')
plt.legend(loc="lower right")
plt.show()

# %%
from sklearn.metrics import f1_score
import numpy as np

# Find the score threshold that gives the best F1 score (for all types together)
y_true = df_test_split['is_truth'].values
y_score = df_test_split['score'].values

thresholds = np.linspace(0, 1, 1001)
f1_scores = [f1_score(y_true, (y_score > thresh).astype(int)) for thresh in thresholds]
best_idx = np.argmax(f1_scores)
best_threshold = thresholds[best_idx]
best_f1 = f1_scores[best_idx]

print(f"Best F1 score: {best_f1:.3f} at threshold: {best_threshold:.3f}")
# Out:
# Best F1 score: 0.404 at threshold: 0.990

# %%
f1_scores = {}

for t in df_test_split['type'].unique():
    mask = df_test_split['type'] == t
    y_true = df_test_split.loc[mask, 'is_truth'].values
    y_pred = (df_test_split.loc[mask, 'score'] > best_threshold).astype(int)
    f1_scores[t] = f1_score(y_true, y_pred)

print(f1_scores)
# Out:
# {'Aktiva': 0.39473684210526316, 'GuV': 0.4044943820224719, 'Passiva': 0.41379310344827586}

# %%
from sklearn.metrics import precision_recall_curve, average_precision_score

plt.figure(figsize=(8, 5))

# Precision-Recall curve for all types together
y_true = df_test_split['is_truth'].values
y_score = df_test_split['score'].values
precision, recall, _ = precision_recall_curve(y_true, y_score)
avg_prec = average_precision_score(y_true, y_score)
plt.plot(recall, precision, label=f'All types (AP = {avg_prec:.3f})')

# Precision-Recall curve per type
for t in df_test_split['type'].unique():
    mask = df_test_split['type'] == t
    y_true_t = df_test_split.loc[mask, 'is_truth'].values
    y_score_t = df_test_split.loc[mask, 'score'].values
    precision_t, recall_t, _ = precision_recall_curve(y_true_t, y_score_t)
    avg_prec_t = average_precision_score(y_true_t, y_score_t)
    plt.plot(recall_t, precision_t, lw=2, label=f'{t} (AP = {avg_prec_t:.3f})')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower left")
plt.show()
