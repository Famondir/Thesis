# %%
from xlsx2html import xlsx2html

out_stream = xlsx2html('/home/simon/Documents/data_science/Thesis/tabula_exports/tabula-AP_Geschaeftsbericht_DE_2023_BBB_Aktiva.xlsx')
out_stream.seek(0)
print(out_stream.read())
# Out:
#     <!DOCTYPE html>
#     <html lang="en">
#     <head>
#         <meta charset="UTF-8">
#         <title>Title</title>
#     </head>
#     <body>
#         <table  style="border-collapse: collapse" border="0" cellspacing="0" cellpadding="0"><colgroup>
# <col  style="width: 391.68px">
# <col  style="width: 100.80000000000001px">
# <col  style="width: 124.80000000000001px">
# <col  style="width: 124.80000000000001px">
# </colgroup>
# <tr>
# <td id="tabula-AP_Geschaeftsbericht_DE_!A1" style="border-bottom: none;border-collapse: collapse;border-left: none;border-right: none;border-top: none;font-size: 10.0px;height: 12.8pt;text-align: general;vertical-align: bottom">AKTIVA</td>
# <td colspan="2" id="tabula-AP_Geschaeftsbericht_DE_!B1" style="border-bottom: none;border-collapse: collapse;border-left: none;border-right: none;border-top: none;font-size: 10.0px;height: 12.8pt;text-align: center;vertical-align: center">31.12.2023</td>
# ...

# %%
# xlsx2html('/home/simon/Documents/data_science/Thesis/tabula_exports/tabula-AP_Geschaeftsbericht_DE_2023_BBB_Aktiva.xlsx', '/home/simon/Documents/data_science/Thesis/tabula_exports/tabula-AP_Geschaeftsbericht_DE_2023_BBB_Aktiva.html')
# Out:
# <_io.TextIOWrapper name='/home/simon/Documents/data_science/Thesis/tabula_exports/tabula-AP_Geschaeftsbericht_DE_2023_BBB_Aktiva.html' mode='w' encoding='utf-8'>
