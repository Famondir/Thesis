# %%
import os
import pandas as pd
from pathlib import Path

def check_gold_truth_mistakes(base_path):
    """
    Check for differences between .xlsx and corresponding .ods files in subfolders.
    
    Args:
        base_path: Path to the main directory containing subfolders
    """
    base_path = Path(base_path)
    results = []
    count_files_without_error = 0
    no_ods = []
    count_files = 0
    count_files_with_error = 0
    
    # Iterate through all subfolders
    for subfolder in base_path.iterdir():
        if not subfolder.is_dir():
            continue
            
        print(f"Processing subfolder: {subfolder.name}")
        
        # Step 1: Find all .xlsx files that do not start with "aktiva_"
        xlsx_files = [f for f in subfolder.glob("*.xlsx") if not f.name.startswith("aktiva_")]
        
        for xlsx_file in xlsx_files:
            print(f"  Found xlsx file: {xlsx_file.name}")
            count_files += 1
            
            # Step 2: Check if corresponding .ods file exists
            base_name = xlsx_file.stem  # filename without extension
            ods_file = subfolder / f"aktiva_{base_name}_MYLA.ods"
            
            if ods_file.exists():
                print(f"    Found corresponding ods file: {ods_file.name}")
                
                try:
                    # Step 3: Load both dataframes
                    df_xlsx = pd.read_excel(xlsx_file)
                    df_ods = pd.read_excel(ods_file, engine='odf')  # Use odf engine for .ods files
                    
                    print(f"    Loaded xlsx: {df_xlsx.shape}, ods: {df_ods.shape}")
                    
                    # Check if required columns exist
                    required_cols = ['E1', 'E2', 'E3', 'year', 'previous_year']
                    
                    xlsx_has_cols = all(col in df_xlsx.columns for col in required_cols)
                    ods_has_cols = all(col in df_ods.columns for col in required_cols)
                    
                    if not xlsx_has_cols:
                        print(f"    Warning: xlsx file missing required columns")
                        continue
                    if not ods_has_cols:
                        print(f"    Warning: ods file missing required columns") 
                        continue
                    
                    # Step 4: Join dataframes and check for differences
                    merged = df_xlsx.merge(df_ods, on=['E1', 'E2', 'E3'], 
                                         suffixes=('_xlsx', '_ods'), how='inner')
                    
                    if merged.empty:
                        print(f"    Warning: No matching rows found for join")
                        continue
                    
                    # Check for differences in year and previous_year columns
                    year_diff = ~(
                        (merged['year_xlsx'] == merged['year_ods']) |
                        (merged['year_xlsx'].isna() & merged['year_ods'].isna())
                    )
                    prev_year_diff = ~(
                        (merged['previous_year_xlsx'] == merged['previous_year_ods']) |
                        (merged['previous_year_xlsx'].isna() & merged['previous_year_ods'].isna())
                    )
                    
                    differences_found = year_diff.any() or prev_year_diff.any()
                    
                    if differences_found:
                        print(f"    *** DIFFERENCES FOUND ***")
                        print(f"        Year differences: {year_diff.sum()} rows")
                        print(f"        Previous year differences: {prev_year_diff.sum()} rows")
                        count_files_with_error += 1
                        
                        # Store detailed results
                        result = {
                            'subfolder': subfolder.name,
                            'xlsx_file': xlsx_file.name,
                            'ods_file': ods_file.name,
                            'total_merged_rows': len(merged),
                            'total_rows_non_nan': merged.notna().sum().sum(),
                            'year_differences': year_diff.sum(),
                            'prev_year_differences': prev_year_diff.sum(),
                            'differences_data': merged[year_diff | prev_year_diff][[#'E1', 'E2', 'E3', 
                                                                                    'year_xlsx', 'year_ods',
                                                                                    'previous_year_xlsx', 'previous_year_ods']]
                        }
                        results.append(result)
                        
                        # Print some example differences
                        # if len(result['differences_data']) > 0:
                        #     print("        Sample differences:")
                        #     print(result['differences_data'].head())
                    else:
                        print(f"    No differences found in year columns")
                        count_files_without_error += 1
                        
                except Exception as e:
                    print(f"    Error processing files: {str(e)}")
            else:
                print(f"    No corresponding ods file found: {ods_file.name}")
                no_ods.append(xlsx_file.name)
    
    print(f"{count_files_without_error} files without errors")
    print(f"{count_files_with_error} files with errors")
    print(f"Total files processed: {count_files}")
    print(f"no_ods: {no_ods}")

    return results

# Run the analysis
base_path = "/home/simon/Documents/data_science/Thesis/micha_gold_truth_aktiva_only_KORRIGIERT/"
results = check_gold_truth_mistakes(base_path)
# Out:
# Processing subfolder: DZHW
#   Found xlsx file: 2023.xlsx
#     Found corresponding ods file: aktiva_2023_MYLA.ods
#     Loaded xlsx: (29, 5), ods: (29, 5)
#     No differences found in year columns
# Processing subfolder: Berliner Werstätten für Menschen mit Behinderung
#   Found xlsx file: Endgultiger Bericht JAP 2022 BWB.xlsx
#     Found corresponding ods file: aktiva_Endgultiger Bericht JAP 2022 BWB_MYLA.ods
#     Loaded xlsx: (29, 5), ods: (29, 5)
#     *** DIFFERENCES FOUND ***
#         Year differences: 0 rows
#         Previous year differences: 1 rows
# Processing subfolder: Friedrichstadt Palast
#   Found xlsx file: 2021-Friedrichstadt-Palast_Jahresbericht.xlsx
#     Found corresponding ods file: aktiva_2021-Friedrichstadt-Palast_Jahresbericht_MYLA.ods
#     Loaded xlsx: (30, 5), ods: (29, 5)
#     *** DIFFERENCES FOUND ***
#         Year differences: 1 rows
#         Previous year differences: 0 rows
# Processing subfolder: Gewobag
#   Found xlsx file: Gewobag-Jahresbericht-2021-HGB.xlsx
#     Found corresponding ods file: aktiva_Gewobag-Jahresbericht-2021-HGB_MYLA.ods
#     Loaded xlsx: (39, 5), ods: (29, 5)
#     *** DIFFERENCES FOUND ***
#         Year differences: 3 rows
#         Previous year differences: 3 rows
# Processing subfolder: Rundfunk Berlin-Brandenburg
#   Found xlsx file: Testat Ebner Stolz rbb JA 2021.xlsx
#     Found corresponding ods file: aktiva_Testat Ebner Stolz rbb JA 2021_MYLA.ods
#     Loaded xlsx: (32, 5), ods: (29, 5)
#     No differences found in year columns
# Processing subfolder: MEAB GmbH
# Processing subfolder: Deutsche Klassenlotterie
#   Found xlsx file: geschaftsbericht_2021.xlsx
#     Found corresponding ods file: aktiva_geschaftsbericht_2021_MYLA.ods
#     Loaded xlsx: (30, 5), ods: (29, 5)
#     No differences found in year columns
# Processing subfolder: WBM GmbH
#   Found xlsx file: WBM_GB2020_web_bf.xlsx
#     Found corresponding ods file: aktiva_WBM_GB2020_web_bf_MYLA.ods
#     Loaded xlsx: (41, 5), ods: (29, 5)
#     *** DIFFERENCES FOUND ***
#         Year differences: 1 rows
#         Previous year differences: 1 rows
# Processing subfolder: Partner für Deutschland
#   Found xlsx file: 2023_PD_Bilanz.xlsx
#     Found corresponding ods file: aktiva_2023_PD_Bilanz_MYLA.ods
#     Loaded xlsx: (29, 5), ods: (29, 5)
#     No differences found in year columns
# Processing subfolder: ITDZ
#   Found xlsx file: jahresbericht-2022.xlsx
#     Found corresponding ods file: aktiva_jahresbericht-2022_MYLA.ods
#     Loaded xlsx: (31, 5), ods: (29, 5)
#     *** DIFFERENCES FOUND ***
#         Year differences: 4 rows
#         Previous year differences: 3 rows
# Processing subfolder: Berliner Bäder Betriebe
#   Found xlsx file: 2018_Geschaeftsbericht_BBB.xlsx
#     Found corresponding ods file: aktiva_2018_Geschaeftsbericht_BBB_MYLA.ods
#     Loaded xlsx: (31, 5), ods: (29, 5)
#     *** DIFFERENCES FOUND ***
#         Year differences: 2 rows
#         Previous year differences: 2 rows
# Processing subfolder: Campus Berlin-Buch
#   Found xlsx file: CBB_2021_Pruefungsbericht_digitale_Ausfertigung.xlsx
#     Found corresponding ods file: aktiva_CBB_2021_Pruefungsbericht_digitale_Ausfertigung_MYLA.ods
#     Loaded xlsx: (31, 5), ods: (29, 5)
#     *** DIFFERENCES FOUND ***
#         Year differences: 1 rows
#         Previous year differences: 1 rows
# Processing subfolder: Helmholtz-Zentrum Berlin GmbH
#   Found xlsx file: jahresabschluss-2023.xlsx
#     Found corresponding ods file: aktiva_jahresabschluss-2023_MYLA.ods
#     Loaded xlsx: (30, 5), ods: (29, 5)
#     *** DIFFERENCES FOUND ***
#         Year differences: 1 rows
#         Previous year differences: 2 rows
# Processing subfolder: HOWOGE
#   Found xlsx file: HOWOGE_HGB_Konzernabschluss_2023.xlsx
#     Found corresponding ods file: aktiva_HOWOGE_HGB_Konzernabschluss_2023_MYLA.ods
#     Loaded xlsx: (38, 5), ods: (29, 5)
#     *** DIFFERENCES FOUND ***
#         Year differences: 1 rows
#         Previous year differences: 1 rows
# Processing subfolder: Berliner Wasserbetriebe
#   Found xlsx file: 2020_geschaeftsbericht-berliner-wasserbetriebe.xlsx
#     Found corresponding ods file: aktiva_2020_geschaeftsbericht-berliner-wasserbetriebe_MYLA.ods
#     Loaded xlsx: (32, 5), ods: (29, 5)
#     *** DIFFERENCES FOUND ***
#         Year differences: 1 rows
#         Previous year differences: 1 rows
# Processing subfolder: Flughafen Berlin-Brandenburg GmbH
#   Found xlsx file: 2019-geschaeftsbericht.xlsx
#     Found corresponding ods file: aktiva_2019-geschaeftsbericht_MYLA.ods
#     Loaded xlsx: (29, 5), ods: (29, 5)
#     *** DIFFERENCES FOUND ***
#         Year differences: 1 rows
#         Previous year differences: 2 rows
# Processing subfolder: Wissenschaftszentrum gGmbH
#   Found xlsx file: digitales Testat_WZB_JAP 2022.xlsx
#     Found corresponding ods file: aktiva_digitales Testat_WZB_JAP 2022_MYLA.ods
#     Loaded xlsx: (31, 5), ods: (29, 5)
#     *** DIFFERENCES FOUND ***
#         Year differences: 3 rows
#         Previous year differences: 2 rows
# Processing subfolder: DEGES
#   Found xlsx file: GB_2024.xlsx
#     Found corresponding ods file: aktiva_GB_2024_MYLA.ods
#     Loaded xlsx: (30, 5), ods: (29, 5)
#     *** DIFFERENCES FOUND ***
#         Year differences: 1 rows
#         Previous year differences: 1 rows
# Processing subfolder: Berlinovo
#   Found xlsx file: berlinovo_gb2018_s.xlsx
#     Found corresponding ods file: aktiva_berlinovo_gb2018_s_MYLA.ods
#     Loaded xlsx: (31, 5), ods: (29, 5)
#     *** DIFFERENCES FOUND ***
#         Year differences: 1 rows
#         Previous year differences: 2 rows
# Processing subfolder: WISTA-Management GmbH
#   Found xlsx file: 2020_WISTA_Bilanz.xlsx
#     Found corresponding ods file: aktiva_2020_WISTA_Bilanz_MYLA.ods
#     Loaded xlsx: (31, 5), ods: (29, 5)
#     *** DIFFERENCES FOUND ***
#         Year differences: 2 rows
#         Previous year differences: 1 rows
# Processing subfolder: Berliner Stadtgüter
#   Found xlsx file: BSG-Geschaeftsbericht-2021-druck.xlsx
#     Found corresponding ods file: aktiva_BSG-Geschaeftsbericht-2021-druck_MYLA.ods
#     Loaded xlsx: (31, 5), ods: (29, 5)
#     *** DIFFERENCES FOUND ***
#         Year differences: 2 rows
#         Previous year differences: 5 rows
# Processing subfolder: Grün Berlin GmbH
#   Found xlsx file: Bilanz_2020.xlsx
#     Found corresponding ods file: aktiva_Bilanz_2020_MYLA.ods
#     Loaded xlsx: (29, 5), ods: (29, 5)
#     *** DIFFERENCES FOUND ***
#         Year differences: 2 rows
#         Previous year differences: 2 rows
# Processing subfolder: Berlinwasser Holding
#   Found xlsx file: 2022-geschaeftsbericht-bwh.xlsx
#     Found corresponding ods file: aktiva_2022-geschaeftsbericht-bwh_MYLA.ods
#     Loaded xlsx: (29, 5), ods: (29, 5)
#     *** DIFFERENCES FOUND ***
#         Year differences: 2 rows
#         Previous year differences: 2 rows
# Processing subfolder: Amt für Statistik Berlin-Brandenburg
#   Found xlsx file: AP_Geschaeftsbericht_DE_2020_BBB.xlsx
#     Found corresponding ods file: aktiva_AP_Geschaeftsbericht_DE_2020_BBB_MYLA.ods
#     Loaded xlsx: (30, 5), ods: (29, 5)
#     No differences found in year columns
#   Found xlsx file: AP_Geschaeftsbericht_DE_2016_BBB.xlsx
#     Found corresponding ods file: aktiva_AP_Geschaeftsbericht_DE_2016_BBB_MYLA.ods
#     Loaded xlsx: (30, 5), ods: (29, 5)
#     *** DIFFERENCES FOUND ***
#         Year differences: 1 rows
#         Previous year differences: 0 rows
#   Found xlsx file: AP_Geschaeftsbericht_DE_2018_BBB.xlsx
#     Found corresponding ods file: aktiva_AP_Geschaeftsbericht_DE_2018_BBB_MYLA.ods
#     Loaded xlsx: (30, 5), ods: (29, 5)
#     No differences found in year columns
#   Found xlsx file: AP_Geschaeftsbericht_DE_2019_BBB.xlsx
#     Found corresponding ods file: aktiva_AP_Geschaeftsbericht_DE_2019_BBB_MYLA.ods
#     Loaded xlsx: (30, 5), ods: (29, 5)
#     No differences found in year columns
#   Found xlsx file: AP_Geschaeftsbericht_DE_2021_BBB.xlsx
#     Found corresponding ods file: aktiva_AP_Geschaeftsbericht_DE_2021_BBB_MYLA.ods
#     Loaded xlsx: (29, 5), ods: (29, 5)
#     No differences found in year columns
#   Found xlsx file: AP_Geschaeftsbericht_DE_2023_BBB.xlsx
#     Found corresponding ods file: aktiva_AP_Geschaeftsbericht_DE_2023_BBB_MYLA.ods
#     Loaded xlsx: (30, 5), ods: (29, 5)
#     No differences found in year columns
#   Found xlsx file: AP_Geschaeftsbericht_DE_2017_BBB.xlsx
#     Found corresponding ods file: aktiva_AP_Geschaeftsbericht_DE_2017_BBB_MYLA.ods
#     Loaded xlsx: (30, 5), ods: (29, 5)
#     *** DIFFERENCES FOUND ***
#         Year differences: 1 rows
#         Previous year differences: 0 rows
#   Found xlsx file: AP_Geschaeftsbericht_DE_2022_BBB.xlsx
#     Found corresponding ods file: aktiva_AP_Geschaeftsbericht_DE_2022_BBB_MYLA.ods
#     Loaded xlsx: (30, 5), ods: (29, 5)
#     No differences found in year columns
#   Found xlsx file: AP_Geschaeftsbericht_DE_2016_BBB_llm.xlsx
#     No corresponding ods file found: aktiva_AP_Geschaeftsbericht_DE_2016_BBB_llm_MYLA.ods
# Processing subfolder: BGZ GmbH
#   Found xlsx file: 20221021-BA-BGZ-JAP-2021.xlsx
#     Found corresponding ods file: aktiva_20221021-BA-BGZ-JAP-2021_MYLA.ods
#     Loaded xlsx: (30, 5), ods: (29, 5)
#     *** DIFFERENCES FOUND ***
#         Year differences: 1 rows
#         Previous year differences: 0 rows
# Processing subfolder: Vivantes
#   Found xlsx file: P180391_Vivantes_GB_Web_190411.xlsx
#     Found corresponding ods file: aktiva_P180391_Vivantes_GB_Web_190411_MYLA.ods
#     Loaded xlsx: (34, 5), ods: (29, 5)
#     *** DIFFERENCES FOUND ***
#         Year differences: 2 rows
#         Previous year differences: 2 rows
# Processing subfolder: Tempelhof Projekt GmbH
#   Found xlsx file: TP_Geschaeftsbericht_2020.xlsx
#     Found corresponding ods file: aktiva_TP_Geschaeftsbericht_2020_MYLA.ods
#     Loaded xlsx: (29, 5), ods: (29, 5)
#     No differences found in year columns
# Processing subfolder: Zoologischer Garten Berlin AG
#   Found xlsx file: ZOO-TIERPARK-Jahresbericht2024.xlsx
#     Found corresponding ods file: aktiva_ZOO-TIERPARK-Jahresbericht2024_MYLA.ods
#     Loaded xlsx: (30, 5), ods: (29, 5)
#     *** DIFFERENCES FOUND ***
#         Year differences: 3 rows
#         Previous year differences: 2 rows
# Processing subfolder: Stadt und Land GmbH
#   Found xlsx file: stadtundland_gb18.xlsx
#     Found corresponding ods file: aktiva_stadtundland_gb18_MYLA.ods
#     Loaded xlsx: (41, 5), ods: (29, 5)
#     *** DIFFERENCES FOUND ***
#         Year differences: 1 rows
#         Previous year differences: 1 rows
# Processing subfolder: GESOBAU AG
#   Found xlsx file: GESOBAU_Geschaeftsbericht_2018.xlsx
#     Found corresponding ods file: aktiva_GESOBAU_Geschaeftsbericht_2018_MYLA.ods
#     Loaded xlsx: (38, 5), ods: (29, 5)
#     No differences found in year columns
# 12 files without errors
# 24 files with errors
# Total files processed: 37
# no_ods: ['AP_Geschaeftsbericht_DE_2016_BBB_llm.xlsx']

# %%
# Summary
print(f"\n=== SUMMARY ===")
print(f"Total files with differences: {len(results)}")
pd.DataFrame(results)[['subfolder', 'xlsx_file', 'year_differences', 'prev_year_differences']]
# for result in results:
#     print(f"{result['subfolder']}/{result['xlsx_file']}: {result['year_differences']} year diffs, {result['prev_year_differences']} prev_year diffs")
# Out:
# === SUMMARY ===
# Total files with differences: 24
#                                            subfolder  \
# 0   Berliner Werstätten für Menschen mit Behinderung
# 1                              Friedrichstadt Palast
# 2                                            Gewobag
# 3                                           WBM GmbH
# 4                                               ITDZ
# 5                            Berliner Bäder Betriebe
# 6                                 Campus Berlin-Buch
# 7                      Helmholtz-Zentrum Berlin GmbH
# 8                                             HOWOGE
# 9                            Berliner Wasserbetriebe
# 10                 Flughafen Berlin-Brandenburg GmbH
# 11                        Wissenschaftszentrum gGmbH
# 12                                             DEGES
# 13                                         Berlinovo
# 14                             WISTA-Management GmbH
# 15                               Berliner Stadtgüter
# 16                                  Grün Berlin GmbH
# 17                              Berlinwasser Holding
# 18              Amt für Statistik Berlin-Brandenburg
# 19              Amt für Statistik Berlin-Brandenburg
# 20                                          BGZ GmbH
# 21                                          Vivantes
# 22                     Zoologischer Garten Berlin AG
# 23                               Stadt und Land GmbH
#
#                                             xlsx_file  year_differences  \
# 0               Endgultiger Bericht JAP 2022 BWB.xlsx                 0
# 1       2021-Friedrichstadt-Palast_Jahresbericht.xlsx                 1
# 2                 Gewobag-Jahresbericht-2021-HGB.xlsx                 3
# 3                              WBM_GB2020_web_bf.xlsx                 1
# 4                             jahresbericht-2022.xlsx                 4
# 5                     2018_Geschaeftsbericht_BBB.xlsx                 2
# 6   CBB_2021_Pruefungsbericht_digitale_Ausfertigun...                 1
# 7                           jahresabschluss-2023.xlsx                 1
# 8               HOWOGE_HGB_Konzernabschluss_2023.xlsx                 1
# 9   2020_geschaeftsbericht-berliner-wasserbetriebe...                 1
# 10                        2019-geschaeftsbericht.xlsx                 1
# 11                 digitales Testat_WZB_JAP 2022.xlsx                 3
# 12                                       GB_2024.xlsx                 1
# 13                            berlinovo_gb2018_s.xlsx                 1
# 14                             2020_WISTA_Bilanz.xlsx                 2
# 15              BSG-Geschaeftsbericht-2021-druck.xlsx                 2
# 16                                   Bilanz_2020.xlsx                 2
# 17                    2022-geschaeftsbericht-bwh.xlsx                 2
# 18              AP_Geschaeftsbericht_DE_2016_BBB.xlsx                 1
# 19              AP_Geschaeftsbericht_DE_2017_BBB.xlsx                 1
# 20                      20221021-BA-BGZ-JAP-2021.xlsx                 1
# 21                P180391_Vivantes_GB_Web_190411.xlsx                 2
# 22                ZOO-TIERPARK-Jahresbericht2024.xlsx                 3
# 23                             stadtundland_gb18.xlsx                 1
#
#     prev_year_differences
# 0                       1
# 1                       0
# 2                       3
# 3                       1
# 4                       3
# 5                       2
# 6                       1
# 7                       2
# 8                       1
# 9                       1
# 10                      2
# 11                      2
# 12                      1
# 13                      2
# 14                      1
# 15                      5
# 16                      2
# 17                      2
# 18                      0
# 19                      0
# 20                      0
# 21                      2
# 22                      2
# 23                      1

# %%
for result in results:
    print(result['differences_data'])
# Out:
#       year_xlsx     year_ods previous_year_xlsx  previous_year_ods
# 25  20186852.78  20186852.78        16365137,11        16365137.11
#     year_xlsx  year_ods  previous_year_xlsx  previous_year_ods
# 22  343987.25  34987.25           279661.94          279661.94
#       year_xlsx     year_ods  previous_year_xlsx  previous_year_ods
# 5    12663753.0   12663753.0           9423157.0          9423175.0
# 14          NaN     318844.0                 NaN           323377.0
# 16     318844.0          NaN            323377.0                NaN
# 24  396487345.0  396487315.0         232416058.0        232416058.0
#     year_xlsx  year_ods  previous_year_xlsx  previous_year_ods
# 18  2038000.0       NaN           1746000.0                NaN
#        year_xlsx     year_ods  previous_year_xlsx  previous_year_ods
# 5   4.794650e+07  47943498.52        4.313806e+07        43138058.43
# 18           NaN         0.00                 NaN          327703.73
# 21  9.667392e+06          NaN        2.130106e+07                NaN
# 25  1.128117e+08  97281289.81        1.292760e+08        93193293.53
#     year_xlsx  year_ods  previous_year_xlsx  previous_year_ods
# 16   45342.99       NaN           448446.21                NaN
# 17        NaN  45342.99                 NaN           48446.21
#     year_xlsx  year_ods  previous_year_xlsx  previous_year_ods
# 18        NaN   2672.67                 NaN          249467.01
#        year_xlsx      year_ods  previous_year_xlsx  previous_year_ods
# 3   5.031300e+05  5.031300e+05        1.272210e+05       1.127221e+06
# 22  3.673975e+08  3.794085e+08        3.521333e+08       3.612640e+08
#      year_xlsx     year_ods  previous_year_xlsx  previous_year_ods
# 3    123928.74   1234928.74            14616.90           14616.90
# 7  95013485.85  95013485.85         89726210.42        89726209.42
#     year_xlsx  year_ods  previous_year_xlsx  previous_year_ods
# 11        NaN    5860.7                 NaN                0.0
#        year_xlsx      year_ods previous_year_xlsx  previous_year_ods
# 2   8.481338e+05  8.481138e+05         1660239.21       1.660239e+06
# 7   3.257537e+09  3.257537e+09      2992054215..4       2.992054e+09
# 15  1.985394e+06  1.985394e+06         2039450.93       2.039541e+06
#     year_xlsx    year_ods  previous_year_xlsx  previous_year_ods
# 3   568344.76    56834.76           177052.31          177052.31
# 20        NaN  9625868.33                 NaN         9697913.90
# 21        NaN   504834.27                 NaN          496884.07
#     year_xlsx      year_ods  previous_year_xlsx  previous_year_ods
# 18        NaN  6.509572e+08                 NaN       5.661777e+08
#     year_xlsx  year_ods  previous_year_xlsx  previous_year_ods
# 23        0.0      0.00                 0.0             143.00
# 27        NaN   3757.13                 NaN           21102.16
#        year_xlsx      year_ods  previous_year_xlsx  previous_year_ods
# 4   1.438726e+08  1.428726e+08         157923748.4        157923748.4
# 16           NaN  9.096000e+06                 NaN          8807000.0
#      year_xlsx    year_ods previous_year_xlsx  previous_year_ods
# 9         0.51         NaN               0.51                NaN
# 11         NaN        0.51                NaN               0.51
# 13  3913700.00  3913700.00           30000000         3000000.00
# 22    71522.27    71522.27          72.757.70           72757.70
# 26    21682.57    21682.57        28798081.13           31998.60
#     year_xlsx   year_ods  previous_year_xlsx  previous_year_ods
# 20   83171.23  344529.59            205000.0           186000.0
# 21  344529.59        NaN            186000.0                NaN
#       year_xlsx     year_ods  previous_year_xlsx  previous_year_ods
# 21  84299084.37          NaN          84192000.0                NaN
# 22          NaN  84299084.37                 NaN         84192000.0
#     year_xlsx  year_ods  previous_year_xlsx  previous_year_ods
# 13        NaN       0.0           2000000.0          2000000.0
#    year_xlsx   year_ods  previous_year_xlsx  previous_year_ods
# 8   520000.0  5200000.0           4400000.0          4400000.0
#       year_xlsx    year_ods  previous_year_xlsx  previous_year_ods
# 22  3654.514.12  3654514.12         12754479.08        12754479.08
#        year_xlsx   year_ods  previous_year_xlsx  previous_year_ods
# 4   5.792969e+08        NaN         587472895.2                NaN
# 11           NaN  7426834.3                 NaN         7668413.34
#      year_xlsx    year_ods  previous_year_xlsx  previous_year_ods
# 9   7755608.92         NaN          1755608.92                NaN
# 10         NaN  7755608.92                 NaN         1755608.92
# 22   252698.40   252695.40           130914.91          130914.91
#     year_xlsx  year_ods  previous_year_xlsx  previous_year_ods
# 18    46222.3       NaN            16935.86                NaN

# %%
import re
import numpy as np

def analyze_difference(row):
    """
    Analyze the difference between xlsx and ods values for possible causes:
    - Comma instead of dot
    - Missing number
    - Swapped number
    """
    results = {}
    for col in ['year', 'previous_year']:
        xlsx_val = row.get(f"{col}_xlsx")
        ods_val = row.get(f"{col}_ods")
        
        # Both NaN: skip
        if pd.isna(xlsx_val) and pd.isna(ods_val):
            results[col] = "both NaN"
            continue
        # One NaN: missing value
        if pd.isna(xlsx_val) or pd.isna(ods_val):
            results[col] = "missing value"
            continue
        
        # Convert to string for analysis
        xlsx_str = str(xlsx_val)
        ods_str = str(ods_val)
        
        # Check for comma/dot confusion
        if ',' in xlsx_str or ',' in ods_str:
            # Try replacing comma with dot and compare as float
            try:
                xlsx_float = float(xlsx_str.replace(',', '.'))
                ods_float = float(ods_str.replace(',', '.'))
                if np.isclose(xlsx_float, ods_float):
                    results[col] = "comma instead of dot"
                    continue
            except Exception:
                pass
        
        # Check for swapped digits (simple case: same length, one swap)
        if len(xlsx_str) == len(ods_str):
            diffs = [(a, b) for a, b in zip(xlsx_str, ods_str) if a != b]
            if len(diffs) == 2 and diffs[0][0] == diffs[1][1] and diffs[0][1] == diffs[1][0]:
                results[col] = "swapped digits"
                continue
        
        # Check for missing digit (length difference of 1)
        if abs(len(xlsx_str) - len(ods_str)) == 1:
            results[col] = "missing digit"
            continue

        if xlsx_str == ods_str:
            results[col] = "same value"
            continue
        
        # Otherwise, just different
        results[col] = "different value"
    return results

# Example: analyze all differences in results
for result in results:
    print(f"\n{result['subfolder']} / {result['xlsx_file']}")
    df = result['differences_data']
    if df.empty:
        print("  No differences data.")
        continue
    for idx, row in df.iterrows():
        analysis = analyze_difference(row)
        print(f"  Row {idx}: {analysis}")
# Out:
# Berliner Werstätten für Menschen mit Behinderung / Endgultiger Bericht JAP 2022 BWB.xlsx
#   Row 25: {'year': 'same value', 'previous_year': 'comma instead of dot'}
#
# Friedrichstadt Palast / 2021-Friedrichstadt-Palast_Jahresbericht.xlsx
#   Row 22: {'year': 'missing digit', 'previous_year': 'same value'}
#
# Gewobag / Gewobag-Jahresbericht-2021-HGB.xlsx
#   Row 5: {'year': 'same value', 'previous_year': 'swapped digits'}
#   Row 14: {'year': 'missing value', 'previous_year': 'missing value'}
#   Row 16: {'year': 'missing value', 'previous_year': 'missing value'}
#   Row 24: {'year': 'different value', 'previous_year': 'same value'}
#
# WBM GmbH / WBM_GB2020_web_bf.xlsx
#   Row 18: {'year': 'missing value', 'previous_year': 'missing value'}
#
# ITDZ / jahresbericht-2022.xlsx
#   Row 5: {'year': 'different value', 'previous_year': 'same value'}
#   Row 18: {'year': 'missing value', 'previous_year': 'missing value'}
#   Row 21: {'year': 'missing value', 'previous_year': 'missing value'}
#   Row 25: {'year': 'missing digit', 'previous_year': 'missing digit'}
#
# Berliner Bäder Betriebe / 2018_Geschaeftsbericht_BBB.xlsx
#   Row 16: {'year': 'missing value', 'previous_year': 'missing value'}
#   Row 17: {'year': 'missing value', 'previous_year': 'missing value'}
#
# Campus Berlin-Buch / CBB_2021_Pruefungsbericht_digitale_Ausfertigung.xlsx
#   Row 18: {'year': 'missing value', 'previous_year': 'missing value'}
#
# Helmholtz-Zentrum Berlin GmbH / jahresabschluss-2023.xlsx
#   Row 3: {'year': 'same value', 'previous_year': 'missing digit'}
#   Row 22: {'year': 'different value', 'previous_year': 'different value'}
#
# HOWOGE / HOWOGE_HGB_Konzernabschluss_2023.xlsx
#   Row 3: {'year': 'missing digit', 'previous_year': 'same value'}
#   Row 7: {'year': 'same value', 'previous_year': 'different value'}
#
# Berliner Wasserbetriebe / 2020_geschaeftsbericht-berliner-wasserbetriebe.xlsx
#   Row 11: {'year': 'missing value', 'previous_year': 'missing value'}
#
# Flughafen Berlin-Brandenburg GmbH / 2019-geschaeftsbericht.xlsx
#   Row 2: {'year': 'different value', 'previous_year': 'same value'}
#   Row 7: {'year': 'same value', 'previous_year': 'different value'}
#   Row 15: {'year': 'same value', 'previous_year': 'swapped digits'}
#
# Wissenschaftszentrum gGmbH / digitales Testat_WZB_JAP 2022.xlsx
#   Row 3: {'year': 'missing digit', 'previous_year': 'same value'}
#   Row 20: {'year': 'missing value', 'previous_year': 'missing value'}
#   Row 21: {'year': 'missing value', 'previous_year': 'missing value'}
#
# DEGES / GB_2024.xlsx
#   Row 18: {'year': 'missing value', 'previous_year': 'missing value'}
#
# Berlinovo / berlinovo_gb2018_s.xlsx
#   Row 23: {'year': 'same value', 'previous_year': 'different value'}
#   Row 27: {'year': 'missing value', 'previous_year': 'missing value'}
#
# WISTA-Management GmbH / 2020_WISTA_Bilanz.xlsx
#   Row 4: {'year': 'different value', 'previous_year': 'same value'}
#   Row 16: {'year': 'missing value', 'previous_year': 'missing value'}
#
# Berliner Stadtgüter / BSG-Geschaeftsbericht-2021-druck.xlsx
#   Row 9: {'year': 'missing value', 'previous_year': 'missing value'}
#   Row 11: {'year': 'missing value', 'previous_year': 'missing value'}
#   Row 13: {'year': 'same value', 'previous_year': 'missing digit'}
#   Row 22: {'year': 'same value', 'previous_year': 'different value'}
#   Row 26: {'year': 'same value', 'previous_year': 'different value'}
#
# Grün Berlin GmbH / Bilanz_2020.xlsx
#   Row 20: {'year': 'missing digit', 'previous_year': 'different value'}
#   Row 21: {'year': 'missing value', 'previous_year': 'missing value'}
#
# Berlinwasser Holding / 2022-geschaeftsbericht-bwh.xlsx
#   Row 21: {'year': 'missing value', 'previous_year': 'missing value'}
#   Row 22: {'year': 'missing value', 'previous_year': 'missing value'}
#
# Amt für Statistik Berlin-Brandenburg / AP_Geschaeftsbericht_DE_2016_BBB.xlsx
#   Row 13: {'year': 'missing value', 'previous_year': 'same value'}
#
# Amt für Statistik Berlin-Brandenburg / AP_Geschaeftsbericht_DE_2017_BBB.xlsx
#   Row 8: {'year': 'missing digit', 'previous_year': 'same value'}
#
# BGZ GmbH / 20221021-BA-BGZ-JAP-2021.xlsx
#   Row 22: {'year': 'missing digit', 'previous_year': 'same value'}
#
# Vivantes / P180391_Vivantes_GB_Web_190411.xlsx
#   Row 4: {'year': 'missing value', 'previous_year': 'missing value'}
#   Row 11: {'year': 'missing value', 'previous_year': 'missing value'}
#
# Zoologischer Garten Berlin AG / ZOO-TIERPARK-Jahresbericht2024.xlsx
#   Row 9: {'year': 'missing value', 'previous_year': 'missing value'}
#   Row 10: {'year': 'missing value', 'previous_year': 'missing value'}
#   Row 22: {'year': 'different value', 'previous_year': 'same value'}
#
# Stadt und Land GmbH / stadtundland_gb18.xlsx
#   Row 18: {'year': 'missing value', 'previous_year': 'missing value'}

# %%
from collections import Counter

error_counter = Counter()

for result in results:
    df = result['differences_data']
    if df.empty:
        continue
    for _, row in df.iterrows():
        analysis = analyze_difference(row)
        for err in analysis.values():
            error_counter[err] += 1

print("Error type counts:")
for err_type, count in error_counter.items():
    print(f"{err_type}: {count}")
# Out:
# Error type counts:
# same value: 21
# comma instead of dot: 1
# missing digit: 10
# swapped digits: 2
# missing value: 49
# different value: 13

# %%
total_non_nan_ods = sum(result.get('total_rows_non_nan', 0) for result in results)
print(f"Total non-NaN values in all used ods files: {total_non_nan_ods}")
# Out:
# Total non-NaN values in all used ods files: 3088

# %%
total_errors = sum(count for err, count in error_counter.items() if err != 'same value')
print(f"Total errors (excluding 'same value'): {total_errors}")
# Out:
# Total errors (excluding 'same value'): 75

# %%
print(round(total_errors/total_non_nan_ods*100, 1))
# Out:
# 2.4
